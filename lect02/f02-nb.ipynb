# %% [raw]
# <!-- -*- mode: markdown; coding: utf-8; fill-column: 60; ispell-dictionary: "english" -*- -->
#
# <meta charset="utf-8"/>
# <meta name="viewport" content="width=device-width,initial-scale=1"/>
# <link rel="stylesheet" href="../style.css">
#
# # More SQL (lecture 2)
#
# Today we'll continue where we left off last time, and then
# learn how to combine several tables in one `SELECT`
# statement.
#
# As usual we have to tell Jupyter to allow SQL:

# %%
# %load_ext sql

# %% [markdown]
# And then we import the database for today's lecture:

# %%
# %sql sqlite:///lect02.sqlite
# Out:
# u'Connected: @lect02.sqlite'

# %% [markdown]
# ## Short review of the first lecture
#
#  +  `SELECT`-`FROM`-`WHERE`:
#
#  +  Set operations: `UNION`, `INTERSECT`, `EXCEPT`
#
#  +  Simple functions: applies to each row of the result,
#     like (you can find their documentation
#     [here](https://www.sqlite.org/lang_corefunc.html)):
#      +  `substr(s, x, y)`
#      +  `instr`/`glob`
#      +  `ltrim`/`rtrim`/`trim`
#      +  `ifnull`/`coalesce`
#      +  `printf`
#      +  `abs`/`round`
#      +  `max(x,y,...)`/`min(x,y,...)` -- observe that this
#         is not the same as the aggregate functions (see
#         below)
#      +  `random`/`randomblob`
#      +  `hex`
#      +  `lower`/`upper`
#
#  +  Aggregate functions (documented
#     [here](https://www.sqlite.org/lang_aggfunc.html)):
#      +  `avg`
#      +  `count`
#      +  `group_concat`
#      +  `max`/`min`
#      +  `sum`/`total`
#
#  +  `GROUP BY` -- splits the rows into groups, and applies
#     aggregate functions on each group (instead of on the
#     whole table)
#
#  +  `GROUP BY` ... `HAVING` -- like `WHERE` for groups
#
#  +  Subqueries -- we can use queries within other queries,
#     typically in a `WHERE ... IN`-statement
#
#
# ## Subqueries, continued...
#
# At the end of the previous lecture, we looked at the
# (admittedly contrieved) question:
#
# **Q:** _Who has shared the chemistry prize with exactly one
# other laureate in years when the summer olympics were held
# in Europe?_

# %%
# %%sql
# SELECT name, year
# FROM nobel
# WHERE category is 'chemistry' AND year IN(
#     SELECT year
#     FROM nobel
#     WHERE category is 'chemistry'
#     GROUP BY year
#     HAVING count(year) = 2
#
#     INTERSECT
#
#     SELECT year
#     FROM olympics
#     WHERE season is 'summer' AND continent is 'Europe')
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Paul Sabatier', 1912),
#  (u'Victor Grignard', 1912),
#  (u'Archer John Porter Martin', 1952),
#  (u'Richard Laurence Millington Synge', 1952),
#  (u'Brian K. Kobilka', 2012),
#  (u'Robert J. Lefkowitz', 2012)]

# %% [markdown]
# We'll save the following problem for the QA-session:
#
# **Q:** _Print the names of all the physics and chemistry
# laureates in years when both categories had laureates with
# names beginning with 'A'?_

# %%
# %%sql

# %% [markdown]
# Another form of subquery is:

# %% [markdown]
# ~~~sql
# SELECT ...,
#        (SELECT ...
#         FROM ...
#         WHERE ...)
# FROM   ...
# ~~~

# %% [markdown]
# This works if the subquery produces one result, such as when
# we use an aggregate function. As an example, solve the
# following problem:
#
# **Q:** _Output the name of all laureates, and the number of
# awards they have -- order first by number of awards, then by
# name, and show only the first 20._

# %%
# %%sql
#
# SELECT DISTINCT name, (
#     SELECT count()
#     FROM nobel AS inner
#     WHERE inner.name is outer.name) AS nbr_of_awards
# FROM nobel AS outer
# ORDER BY nbr_of_awards DESC, name
# LIMIT 20
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Frederick Sanger', 2),
#  (u'John Bardeen', 2),
#  (u'Marie Curie, n\xe9e Sklodowska', 2),
#  (u'Aage Niels Bohr', 1),
#  (u'Aaron Ciechanover', 1),
#  (u'Aaron Klug', 1),
#  (u'Abdus Salam', 1),
#  (u'Ada E. Yonath', 1),
#  (u'Adam G. Riess', 1),
#  (u'Adolf Friedrich Johann Butenandt', 1),
#  (u'Adolf Otto Reinhold Windaus', 1),
#  (u'Ahmed H. Zewail', 1),
#  (u'Akira Suzuki', 1),
#  (u'Akira Yoshino', 1),
#  (u'Alan G. MacDiarmid', 1),
#  (u'Alan J. Heeger', 1),
#  (u'Alan Lloyd Hodgkin', 1),
#  (u'Albert Abraham Michelson', 1),
#  (u'Albert Camus', 1),
#  (u'Albert Claude', 1)]

# %% [markdown]
# This is called a _correlated subquery_ (since we refer to
# the enclosing query inside it). We use an alias to
# distinguish between the nobel table in the outer query and
# the nobel table in the subquery (it's the same table, but we
# 'iterate' through it separately).
#
#
#
# ## Redundancy, and the case for splitting up tables
#
# The term
# [redundancy](https://en.wikipedia.org/wiki/Redundancy_(linguistics))
# can be defined in many contexts, in linguistics (and in
# general) it refers to information which is expressed more
# than once. It is sometimes desirable (the human body has an
# enormous amount of redundancy, and that's what enable us to
# self-heal), but often it is a source of confusion and
# errors.
#
# Our table of Olympic Games looks like this:

# %%
# %%sql
# SELECT *
# FROM   olympics
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(1924, u'Chamonix', u'France', u'Europe', u'winter', u'I'),
#  (1928, u'St. Moritz', u'Switzerland', u'Europe', u'winter', u'II'),
#  (1932, u'Lake Placid', u'United States', u'North America', u'winter', u'III'),
#  (1936, u'Garmisch-Partenkirchen', u'Germany', u'Europe', u'winter', u'IV'),
#  (1948, u'St. Moritz', u' Switzerland', u'Europe', u'winter', u'V'),
#  (1952, u'Oslo', u'Norway', u'Europe', u'winter', u'VI'),
#  (1956, u"Cortina d'Ampezzo", u'Italy', u'Europe', u'winter', u'VII'),
#  (1960, u'Squaw Valley', u'United States', u'North America', u'winter', u'VIII'),
#  (1964, u'Innsbruck', u'Austria', u'Europe', u'winter', u'IX'),
#  (1968, u'Grenoble', u'France', u'Europe', u'winter', u'X'),
#  (1972, u'Sapporo', u'Japan', u'Asia', u'winter', u'XI'),
#  (1976, u'Innsbruck', u'Austria', u'Europe', u'winter', u'XII'),
#  (1980, u'Lake Placid', u'United States', u'North America', u'winter', u'XIII'),
#  (1984, u'Sarajevo', u'Yugoslavia', u'Europe', u'winter', u'XIV'),
#  (1988, u'Calgary', u'Canada', u'North America', u'winter', u'XV'),
#  (1992, u'Albertville', u'France', u'Europe', u'winter', u'XVI'),
#  (1994, u'Lillehammer', u'Norway', u'Europe', u'winter', u'XVII'),
#  (1998, u'Nagano', u'Japan', u'Asia', u'winter', u'XVIII'),
#  (2002, u'Salt Lake City', u'United States', u'North America', u'winter', u'XIX'),
#  (2006, u'Turin', u'Italy', u'Europe', u'winter', u'XX'),
#  (2010, u'Vancouver', u'Canada', u'North America', u'winter', u'XXI'),
#  (2014, u'Sochi', u'Russia', u'Europe', u'winter', u'XXII'),
#  (2018, u'Pyeongchang', u'South Korea', u'Asia', u'winter', u'XXIII'),
#  (1896, u'Athens', u'Greece', u'Europe', u'summer', u'I'),
#  (1900, u'Paris', u'France', u'Europe', u'summer', u'II'),
#  (1904, u'St. Louis', u'United States', u'North America', u'summer', u'III'),
#  (1908, u'London', u'United Kingdom', u'Europe', u'summer', u'IV'),
#  (1912, u'Stockholm', u'Sweden', u'Europe', u'summer', u'V'),
#  (1916, u'Berlin', u'Germany', u'Europe', u'summer', u'VI'),
#  (1920, u'Antwerp', u'Belgium', u'Europe', u'summer', u'VII'),
#  (1924, u'Paris', u'France', u'Europe', u'summer', u'VIII'),
#  (1928, u'Amsterdam', u'Netherlands', u'Europe', u'summer', u'IX'),
#  (1932, u'Los Angeles', u'United States', u'North America', u'summer', u'X'),
#  (1936, u'Berlin', u'Germany', u'Europe', u'summer', u'XI'),
#  (1948, u'London', u'United Kingdom', u'Europe', u'summer', u'XIV'),
#  (1952, u'Helsinki', u'Finland', u'Europe', u'summer', u'XV'),
#  (1956, u'Melbourne', u'Australia', u'Australia', u'summer', u'XVII'),
#  (1960, u'Rome', u'Italy', u'Europe', u'summer', u'XVII'),
#  (1964, u'Tokyo', u'Japan', u'Asia', u'summer', u'XVIII'),
#  (1968, u'Mexico City', u'Mexico', u'North America', u'summer', u'XIX'),
#  (1972, u'Munich', u'West Germany', u'Europe', u'summer', u'XX'),
#  (1976, u'Montreal', u'Canada', u'North America', u'summer', u'XXI'),
#  (1980, u'Moscow', u'Soviet Union', u'Europe', u'summer', u'XXII'),
#  (1984, u'Los Angeles', u'United States', u'North America', u'summer', u'XXIII'),
#  (1988, u'Seoul', u'South Korea', u'Asia', u'summer', u'XXIV'),
#  (1992, u'Barcelona', u'Spain', u'Europe', u'summer', u'XXV'),
#  (1996, u'Atlanta', u'United States', u'North America', u'summer', u'XXVI'),
#  (2000, u'Sydney', u'Australia', u'Australia', u'summer', u'XXVII'),
#  (2004, u'Athens', u'Greece', u'Europe', u'summer', u'XXVIII'),
#  (2008, u'Beijing', u'China', u'Asia', u'summer', u'XXIX'),
#  (2012, u'London', u'United Kingdom', u'Europe', u'summer', u'XXX'),
#  (2016, u'Rio de Janeiro', u'Brazil', u'South America', u'summer', u'XXXI')]

# %% [markdown]
# **Exercise:** _Can you see any potential sources of
# redundancy?_
#
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# Two things come to mind:
#
#  * A city seldom changes country (although it happens...),
#    so repeating the same pairs of (city, country) in several
#    places may seem redundant.
#
#  * A country never moves to another continent, so repeating
#    the same pairs of (country, continent) is always
#    redundant.
#
# In the first case, there might be a reason to save both the
# city name and the country name, not only because counties
# historically have changed (in 1980 Moscow was in the Soviet
# Union, and in 1984 Sarajevo was in Yugoslavia), but also
# because city names aren't globally unique -- there is a
# Paris in Texas, and a Moscow in Kansas. So we may need the
# country to identify the city uniquely. In this case we say
# that the pair (city, country) is a _key_ (we'll return to
# this many times during the course).
#
# But saving the same pair of country and continent in several
# places is just redundant, and it is not only wasteful
# memory-wise, but could also lead to some problems when we
# modify our table (we'll return to this when we talk about
# _normalization_).
#
# We say that the continent is _functionally dependent_ on the
# country (or that there is a _functional dependency_ from
# countries to continents), and we can avoid the redundancy it
# gives rise to by creating a new table, which tells on which
# continent each country is. We'll return to the details of
# the SQL statements below later in the course, you're not
# supposed to understand it right now, but if we evaluate the
# cell below we'll get two tables, `better_olympics` and
# `continents` who could replace our old `olympics`:

# %%
# %%sql
# DROP TABLE IF EXISTS continents;
# CREATE TABLE continents (
#   country   TEXT,
#   continent TEXT NOT NULL,
#   PRIMARY KEY (country)
# );
#
# INSERT OR IGNORE
# INTO   continents(country, continent)
# SELECT country, continent
# FROM   olympics;
#
# DROP TABLE IF EXISTS better_olympics;
# CREATE TABLE  better_olympics (
#   year            INT,
#   city            TEXT,
#   country         TEXT,
#   season          TEXT,
#   ordinal_number  TEXT,
#   PRIMARY KEY (year, season)
# );
#
# INSERT
# INTO   better_olympics(year, city, country, season, ordinal_number)
# SELECT year, city, country, season, ordinal_number
# FROM   olympics;
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# Done.
# 26 rows affected.
# Done.
# Done.
# 52 rows affected.
# []

# %% [markdown]
# Now we don't have to enter the continent the next time
# Athens, Paris or London is awarded the games.
#
# Our two tables look like this:

# %%
# %%sql
# SELECT *
# FROM   better_olympics;
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(1924, u'Chamonix', u'France', u'winter', u'I'),
#  (1928, u'St. Moritz', u'Switzerland', u'winter', u'II'),
#  (1932, u'Lake Placid', u'United States', u'winter', u'III'),
#  (1936, u'Garmisch-Partenkirchen', u'Germany', u'winter', u'IV'),
#  (1948, u'St. Moritz', u' Switzerland', u'winter', u'V'),
#  (1952, u'Oslo', u'Norway', u'winter', u'VI'),
#  (1956, u"Cortina d'Ampezzo", u'Italy', u'winter', u'VII'),
#  (1960, u'Squaw Valley', u'United States', u'winter', u'VIII'),
#  (1964, u'Innsbruck', u'Austria', u'winter', u'IX'),
#  (1968, u'Grenoble', u'France', u'winter', u'X'),
#  (1972, u'Sapporo', u'Japan', u'winter', u'XI'),
#  (1976, u'Innsbruck', u'Austria', u'winter', u'XII'),
#  (1980, u'Lake Placid', u'United States', u'winter', u'XIII'),
#  (1984, u'Sarajevo', u'Yugoslavia', u'winter', u'XIV'),
#  (1988, u'Calgary', u'Canada', u'winter', u'XV'),
#  (1992, u'Albertville', u'France', u'winter', u'XVI'),
#  (1994, u'Lillehammer', u'Norway', u'winter', u'XVII'),
#  (1998, u'Nagano', u'Japan', u'winter', u'XVIII'),
#  (2002, u'Salt Lake City', u'United States', u'winter', u'XIX'),
#  (2006, u'Turin', u'Italy', u'winter', u'XX'),
#  (2010, u'Vancouver', u'Canada', u'winter', u'XXI'),
#  (2014, u'Sochi', u'Russia', u'winter', u'XXII'),
#  (2018, u'Pyeongchang', u'South Korea', u'winter', u'XXIII'),
#  (1896, u'Athens', u'Greece', u'summer', u'I'),
#  (1900, u'Paris', u'France', u'summer', u'II'),
#  (1904, u'St. Louis', u'United States', u'summer', u'III'),
#  (1908, u'London', u'United Kingdom', u'summer', u'IV'),
#  (1912, u'Stockholm', u'Sweden', u'summer', u'V'),
#  (1916, u'Berlin', u'Germany', u'summer', u'VI'),
#  (1920, u'Antwerp', u'Belgium', u'summer', u'VII'),
#  (1924, u'Paris', u'France', u'summer', u'VIII'),
#  (1928, u'Amsterdam', u'Netherlands', u'summer', u'IX'),
#  (1932, u'Los Angeles', u'United States', u'summer', u'X'),
#  (1936, u'Berlin', u'Germany', u'summer', u'XI'),
#  (1948, u'London', u'United Kingdom', u'summer', u'XIV'),
#  (1952, u'Helsinki', u'Finland', u'summer', u'XV'),
#  (1956, u'Melbourne', u'Australia', u'summer', u'XVII'),
#  (1960, u'Rome', u'Italy', u'summer', u'XVII'),
#  (1964, u'Tokyo', u'Japan', u'summer', u'XVIII'),
#  (1968, u'Mexico City', u'Mexico', u'summer', u'XIX'),
#  (1972, u'Munich', u'West Germany', u'summer', u'XX'),
#  (1976, u'Montreal', u'Canada', u'summer', u'XXI'),
#  (1980, u'Moscow', u'Soviet Union', u'summer', u'XXII'),
#  (1984, u'Los Angeles', u'United States', u'summer', u'XXIII'),
#  (1988, u'Seoul', u'South Korea', u'summer', u'XXIV'),
#  (1992, u'Barcelona', u'Spain', u'summer', u'XXV'),
#  (1996, u'Atlanta', u'United States', u'summer', u'XXVI'),
#  (2000, u'Sydney', u'Australia', u'summer', u'XXVII'),
#  (2004, u'Athens', u'Greece', u'summer', u'XXVIII'),
#  (2008, u'Beijing', u'China', u'summer', u'XXIX'),
#  (2012, u'London', u'United Kingdom', u'summer', u'XXX'),
#  (2016, u'Rio de Janeiro', u'Brazil', u'summer', u'XXXI')]

# %%
# %%sql
# SELECT *
# FROM   continents;
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'France', u'Europe'),
#  (u'Switzerland', u'Europe'),
#  (u'United States', u'North America'),
#  (u'Germany', u'Europe'),
#  (u' Switzerland', u'Europe'),
#  (u'Norway', u'Europe'),
#  (u'Italy', u'Europe'),
#  (u'Austria', u'Europe'),
#  (u'Japan', u'Asia'),
#  (u'Yugoslavia', u'Europe'),
#  (u'Canada', u'North America'),
#  (u'Russia', u'Europe'),
#  (u'South Korea', u'Asia'),
#  (u'Greece', u'Europe'),
#  (u'United Kingdom', u'Europe'),
#  (u'Sweden', u'Europe'),
#  (u'Belgium', u'Europe'),
#  (u'Netherlands', u'Europe'),
#  (u'Finland', u'Europe'),
#  (u'Australia', u'Australia'),
#  (u'Mexico', u'North America'),
#  (u'West Germany', u'Europe'),
#  (u'Soviet Union', u'Europe'),
#  (u'Spain', u'Europe'),
#  (u'China', u'Asia'),
#  (u'Brazil', u'South America')]

# %% [markdown]
# We've avoided some redundancy, but now we need a way to
# combine the information in our two tables, and that's what
# _joins_ are for...
#
#
# ## Joining tables together
#
# We want a database for handling college applications, a
# number of students applies for various majors at different
# colleges. We want to keep track of:
#
#  + student id (similar to stil-id)
#  + student name
#  + student's grade average (gpa)
#  + the size of the student's highschool
#  + the names of the colleges
#  + the state for each college
#  + the enrollment for each college
#  + the major applied for
#  + the decision ('Y' for accepted, 'N' otherwise)
#
# One way of doing this would be to use one big table:

# %%
# %%sql
# SELECT *
# FROM   big_college
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Amy', 3.9, 1000, u'Berkeley', u'CA', 36000, u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Cornell', u'NY', 21000, u'EE', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'CA', 15000, u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'CA', 15000, u'EE', u'N'),
#  (234, u'Bob', 3.6, 1500, u'Berkeley', u'CA', 36000, u'biology', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'NY', 21000, u'CS', u'Y'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'NY', 21000, u'EE', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'NY', 21000, u'bioengineering', u'N'),
#  (345, u'Craig', 3.5, 500, u'MIT', u'MA', 10000, u'bioengineering', u'Y'),
#  (456, u'Doris', 3.9, 1000, None, None, None, None, None),
#  (543, u'Craig', 3.4, 2000, u'MIT', u'MA', 10000, u'CS', u'N'),
#  (567, u'Edward', 2.9, 2000, None, None, None, None, None),
#  (654, u'Amy', 3.9, 1000, None, None, None, None, None),
#  (678, u'Fay', 3.8, 200, u'Stanford', u'CA', 15000, u'history', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'NY', 21000, u'history', u'N'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'NY', 21000, u'psychology', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Stanford', u'CA', 15000, u'history', u'Y'),
#  (789, u'Gary', 3.4, 800, None, None, None, None, None),
#  (876, u'Irene', 3.9, 400, u'MIT', u'MA', 10000, u'biology', u'Y'),
#  (876, u'Irene', 3.9, 400, u'MIT', u'MA', 10000, u'marine biology', u'N'),
#  (876, u'Irene', 3.9, 400, u'Stanford', u'CA', 15000, u'CS', u'N'),
#  (987, u'Helen', 3.7, 800, u'Berkeley', u'CA', 36000, u'CS', u'Y'),
#  (987, u'Helen', 3.7, 800, u'Stanford', u'CA', 15000, u'CS', u'Y')]

# %% [markdown]
# But, just as with our olympics database above, this would
# give us a lot of redundance, so we'd like to split this big
# table into several related tables.
#
# In lectures 7 and 8 we'll discuss the theory and practice of
# splitting up tables -- for now, suggest tables which you
# think would make working with our data easier.
#
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# We have one table for the students:

# %%
# %%sql
# SELECT *
# FROM   students
# LIMIT 4
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Amy', 3.9, 1000),
#  (234, u'Bob', 3.6, 1500),
#  (345, u'Craig', 3.5, 500),
#  (456, u'Doris', 3.9, 1000)]

# %% [markdown]
# One for the colleges:

# %%
# %%sql
# SELECT *
# FROM   colleges
# LIMIT 4
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Stanford', u'CA', 15000),
#  (u'Berkeley', u'CA', 36000),
#  (u'MIT', u'MA', 10000),
#  (u'Cornell', u'NY', 21000)]

# %% [markdown]
# And one for all collage applications made by the students:

# %%
# %%sql
# SELECT *
# FROM   applications
# LIMIT 4
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Stanford', u'CS', u'Y'),
#  (123, u'Stanford', u'EE', u'N'),
#  (123, u'Berkeley', u'CS', u'Y'),
#  (123, u'Cornell', u'EE', u'Y')]

# %% [markdown]
# The `applications` table uses `s_id` instead of `s_name`,
# since we could have several students with the same name (we
# actually have two 'Amy') -- `s_id` is guaranteed to be
# unique (we'll talk _much_ more about uniqueness next week).
#
# Now assume we want to display all applications, _with the
# names of the students_ (not just student id). We then need a
# way to combine information in the `applications` table with
# information in the `students` table, and we'll do it with a
# _join_.
#
#
# The SQL standard specifies five different kinds of joins:
#
#  + _cross join_
#  + _inner join_
#  + _left outer join_
#  + _right outer join_
#  + _full outer join_
#
# The most primitive of these is the cross join -- we can
# write it as:

# %% [markdown]
# ~~~
# SELECT      *
# FROM        a
# CROSS JOIN  b
# ~~~

# %% [markdown]
# Doing this, we get all combinations of rows from each of
# table `a` and `b` -- the rows will contain all attributes
# from both tables (unless we make a projection).
#
# If we do it with our `applications` and `students` tables we
# get:

# %%
# %%sql
# SELECT      *
# FROM        applications
# CROSS JOIN  students
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Stanford', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (123, u'Stanford', u'CS', u'Y', 234, u'Bob', 3.6, 1500),
#  (123, u'Stanford', u'CS', u'Y', 345, u'Craig', 3.5, 500),
#  (123, u'Stanford', u'CS', u'Y', 456, u'Doris', 3.9, 1000),
#  (123, u'Stanford', u'CS', u'Y', 543, u'Craig', 3.4, 2000),
#  (123, u'Stanford', u'CS', u'Y', 567, u'Edward', 2.9, 2000),
#  (123, u'Stanford', u'CS', u'Y', 654, u'Amy', 3.9, 1000),
#  (123, u'Stanford', u'CS', u'Y', 678, u'Fay', 3.8, 200),
#  (123, u'Stanford', u'CS', u'Y', 765, u'Jay', 2.9, 1500),
#  (123, u'Stanford', u'CS', u'Y', 789, u'Gary', 3.4, 800),
#  (123, u'Stanford', u'CS', u'Y', 876, u'Irene', 3.9, 400),
#  (123, u'Stanford', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (123, u'Stanford', u'EE', u'N', 123, u'Amy', 3.9, 1000),
#  (123, u'Stanford', u'EE', u'N', 234, u'Bob', 3.6, 1500),
#  (123, u'Stanford', u'EE', u'N', 345, u'Craig', 3.5, 500),
#  (123, u'Stanford', u'EE', u'N', 456, u'Doris', 3.9, 1000),
#  (123, u'Stanford', u'EE', u'N', 543, u'Craig', 3.4, 2000),
#  (123, u'Stanford', u'EE', u'N', 567, u'Edward', 2.9, 2000),
#  (123, u'Stanford', u'EE', u'N', 654, u'Amy', 3.9, 1000),
#  (123, u'Stanford', u'EE', u'N', 678, u'Fay', 3.8, 200),
#  (123, u'Stanford', u'EE', u'N', 765, u'Jay', 2.9, 1500),
#  (123, u'Stanford', u'EE', u'N', 789, u'Gary', 3.4, 800),
#  (123, u'Stanford', u'EE', u'N', 876, u'Irene', 3.9, 400),
#  (123, u'Stanford', u'EE', u'N', 987, u'Helen', 3.7, 800),
#  (123, u'Berkeley', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (123, u'Berkeley', u'CS', u'Y', 234, u'Bob', 3.6, 1500),
#  (123, u'Berkeley', u'CS', u'Y', 345, u'Craig', 3.5, 500),
#  (123, u'Berkeley', u'CS', u'Y', 456, u'Doris', 3.9, 1000),
#  (123, u'Berkeley', u'CS', u'Y', 543, u'Craig', 3.4, 2000),
#  (123, u'Berkeley', u'CS', u'Y', 567, u'Edward', 2.9, 2000),
#  (123, u'Berkeley', u'CS', u'Y', 654, u'Amy', 3.9, 1000),
#  (123, u'Berkeley', u'CS', u'Y', 678, u'Fay', 3.8, 200),
#  (123, u'Berkeley', u'CS', u'Y', 765, u'Jay', 2.9, 1500),
#  (123, u'Berkeley', u'CS', u'Y', 789, u'Gary', 3.4, 800),
#  (123, u'Berkeley', u'CS', u'Y', 876, u'Irene', 3.9, 400),
#  (123, u'Berkeley', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (123, u'Cornell', u'EE', u'Y', 123, u'Amy', 3.9, 1000),
#  (123, u'Cornell', u'EE', u'Y', 234, u'Bob', 3.6, 1500),
#  (123, u'Cornell', u'EE', u'Y', 345, u'Craig', 3.5, 500),
#  (123, u'Cornell', u'EE', u'Y', 456, u'Doris', 3.9, 1000),
#  (123, u'Cornell', u'EE', u'Y', 543, u'Craig', 3.4, 2000),
#  (123, u'Cornell', u'EE', u'Y', 567, u'Edward', 2.9, 2000),
#  (123, u'Cornell', u'EE', u'Y', 654, u'Amy', 3.9, 1000),
#  (123, u'Cornell', u'EE', u'Y', 678, u'Fay', 3.8, 200),
#  (123, u'Cornell', u'EE', u'Y', 765, u'Jay', 2.9, 1500),
#  (123, u'Cornell', u'EE', u'Y', 789, u'Gary', 3.4, 800),
#  (123, u'Cornell', u'EE', u'Y', 876, u'Irene', 3.9, 400),
#  (123, u'Cornell', u'EE', u'Y', 987, u'Helen', 3.7, 800),
#  (234, u'Berkeley', u'biology', u'N', 123, u'Amy', 3.9, 1000),
#  (234, u'Berkeley', u'biology', u'N', 234, u'Bob', 3.6, 1500),
#  (234, u'Berkeley', u'biology', u'N', 345, u'Craig', 3.5, 500),
#  (234, u'Berkeley', u'biology', u'N', 456, u'Doris', 3.9, 1000),
#  (234, u'Berkeley', u'biology', u'N', 543, u'Craig', 3.4, 2000),
#  (234, u'Berkeley', u'biology', u'N', 567, u'Edward', 2.9, 2000),
#  (234, u'Berkeley', u'biology', u'N', 654, u'Amy', 3.9, 1000),
#  (234, u'Berkeley', u'biology', u'N', 678, u'Fay', 3.8, 200),
#  (234, u'Berkeley', u'biology', u'N', 765, u'Jay', 2.9, 1500),
#  (234, u'Berkeley', u'biology', u'N', 789, u'Gary', 3.4, 800),
#  (234, u'Berkeley', u'biology', u'N', 876, u'Irene', 3.9, 400),
#  (234, u'Berkeley', u'biology', u'N', 987, u'Helen', 3.7, 800),
#  (345, u'MIT', u'bioengineering', u'Y', 123, u'Amy', 3.9, 1000),
#  (345, u'MIT', u'bioengineering', u'Y', 234, u'Bob', 3.6, 1500),
#  (345, u'MIT', u'bioengineering', u'Y', 345, u'Craig', 3.5, 500),
#  (345, u'MIT', u'bioengineering', u'Y', 456, u'Doris', 3.9, 1000),
#  (345, u'MIT', u'bioengineering', u'Y', 543, u'Craig', 3.4, 2000),
#  (345, u'MIT', u'bioengineering', u'Y', 567, u'Edward', 2.9, 2000),
#  (345, u'MIT', u'bioengineering', u'Y', 654, u'Amy', 3.9, 1000),
#  (345, u'MIT', u'bioengineering', u'Y', 678, u'Fay', 3.8, 200),
#  (345, u'MIT', u'bioengineering', u'Y', 765, u'Jay', 2.9, 1500),
#  (345, u'MIT', u'bioengineering', u'Y', 789, u'Gary', 3.4, 800),
#  (345, u'MIT', u'bioengineering', u'Y', 876, u'Irene', 3.9, 400),
#  (345, u'MIT', u'bioengineering', u'Y', 987, u'Helen', 3.7, 800),
#  (345, u'Cornell', u'bioengineering', u'N', 123, u'Amy', 3.9, 1000),
#  (345, u'Cornell', u'bioengineering', u'N', 234, u'Bob', 3.6, 1500),
#  (345, u'Cornell', u'bioengineering', u'N', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'bioengineering', u'N', 456, u'Doris', 3.9, 1000),
#  (345, u'Cornell', u'bioengineering', u'N', 543, u'Craig', 3.4, 2000),
#  (345, u'Cornell', u'bioengineering', u'N', 567, u'Edward', 2.9, 2000),
#  (345, u'Cornell', u'bioengineering', u'N', 654, u'Amy', 3.9, 1000),
#  (345, u'Cornell', u'bioengineering', u'N', 678, u'Fay', 3.8, 200),
#  (345, u'Cornell', u'bioengineering', u'N', 765, u'Jay', 2.9, 1500),
#  (345, u'Cornell', u'bioengineering', u'N', 789, u'Gary', 3.4, 800),
#  (345, u'Cornell', u'bioengineering', u'N', 876, u'Irene', 3.9, 400),
#  (345, u'Cornell', u'bioengineering', u'N', 987, u'Helen', 3.7, 800),
#  (345, u'Cornell', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (345, u'Cornell', u'CS', u'Y', 234, u'Bob', 3.6, 1500),
#  (345, u'Cornell', u'CS', u'Y', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'CS', u'Y', 456, u'Doris', 3.9, 1000),
#  (345, u'Cornell', u'CS', u'Y', 543, u'Craig', 3.4, 2000),
#  (345, u'Cornell', u'CS', u'Y', 567, u'Edward', 2.9, 2000),
#  (345, u'Cornell', u'CS', u'Y', 654, u'Amy', 3.9, 1000),
#  (345, u'Cornell', u'CS', u'Y', 678, u'Fay', 3.8, 200),
#  (345, u'Cornell', u'CS', u'Y', 765, u'Jay', 2.9, 1500),
#  (345, u'Cornell', u'CS', u'Y', 789, u'Gary', 3.4, 800),
#  (345, u'Cornell', u'CS', u'Y', 876, u'Irene', 3.9, 400),
#  (345, u'Cornell', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (345, u'Cornell', u'EE', u'N', 123, u'Amy', 3.9, 1000),
#  (345, u'Cornell', u'EE', u'N', 234, u'Bob', 3.6, 1500),
#  (345, u'Cornell', u'EE', u'N', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'EE', u'N', 456, u'Doris', 3.9, 1000),
#  (345, u'Cornell', u'EE', u'N', 543, u'Craig', 3.4, 2000),
#  (345, u'Cornell', u'EE', u'N', 567, u'Edward', 2.9, 2000),
#  (345, u'Cornell', u'EE', u'N', 654, u'Amy', 3.9, 1000),
#  (345, u'Cornell', u'EE', u'N', 678, u'Fay', 3.8, 200),
#  (345, u'Cornell', u'EE', u'N', 765, u'Jay', 2.9, 1500),
#  (345, u'Cornell', u'EE', u'N', 789, u'Gary', 3.4, 800),
#  (345, u'Cornell', u'EE', u'N', 876, u'Irene', 3.9, 400),
#  (345, u'Cornell', u'EE', u'N', 987, u'Helen', 3.7, 800),
#  (678, u'Stanford', u'history', u'Y', 123, u'Amy', 3.9, 1000),
#  (678, u'Stanford', u'history', u'Y', 234, u'Bob', 3.6, 1500),
#  (678, u'Stanford', u'history', u'Y', 345, u'Craig', 3.5, 500),
#  (678, u'Stanford', u'history', u'Y', 456, u'Doris', 3.9, 1000),
#  (678, u'Stanford', u'history', u'Y', 543, u'Craig', 3.4, 2000),
#  (678, u'Stanford', u'history', u'Y', 567, u'Edward', 2.9, 2000),
#  (678, u'Stanford', u'history', u'Y', 654, u'Amy', 3.9, 1000),
#  (678, u'Stanford', u'history', u'Y', 678, u'Fay', 3.8, 200),
#  (678, u'Stanford', u'history', u'Y', 765, u'Jay', 2.9, 1500),
#  (678, u'Stanford', u'history', u'Y', 789, u'Gary', 3.4, 800),
#  (678, u'Stanford', u'history', u'Y', 876, u'Irene', 3.9, 400),
#  (678, u'Stanford', u'history', u'Y', 987, u'Helen', 3.7, 800),
#  (987, u'Stanford', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (987, u'Stanford', u'CS', u'Y', 234, u'Bob', 3.6, 1500),
#  (987, u'Stanford', u'CS', u'Y', 345, u'Craig', 3.5, 500),
#  (987, u'Stanford', u'CS', u'Y', 456, u'Doris', 3.9, 1000),
#  (987, u'Stanford', u'CS', u'Y', 543, u'Craig', 3.4, 2000),
#  (987, u'Stanford', u'CS', u'Y', 567, u'Edward', 2.9, 2000),
#  (987, u'Stanford', u'CS', u'Y', 654, u'Amy', 3.9, 1000),
#  (987, u'Stanford', u'CS', u'Y', 678, u'Fay', 3.8, 200),
#  (987, u'Stanford', u'CS', u'Y', 765, u'Jay', 2.9, 1500),
#  (987, u'Stanford', u'CS', u'Y', 789, u'Gary', 3.4, 800),
#  (987, u'Stanford', u'CS', u'Y', 876, u'Irene', 3.9, 400),
#  (987, u'Stanford', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (987, u'Berkeley', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (987, u'Berkeley', u'CS', u'Y', 234, u'Bob', 3.6, 1500),
#  (987, u'Berkeley', u'CS', u'Y', 345, u'Craig', 3.5, 500),
#  (987, u'Berkeley', u'CS', u'Y', 456, u'Doris', 3.9, 1000),
#  (987, u'Berkeley', u'CS', u'Y', 543, u'Craig', 3.4, 2000),
#  (987, u'Berkeley', u'CS', u'Y', 567, u'Edward', 2.9, 2000),
#  (987, u'Berkeley', u'CS', u'Y', 654, u'Amy', 3.9, 1000),
#  (987, u'Berkeley', u'CS', u'Y', 678, u'Fay', 3.8, 200),
#  (987, u'Berkeley', u'CS', u'Y', 765, u'Jay', 2.9, 1500),
#  (987, u'Berkeley', u'CS', u'Y', 789, u'Gary', 3.4, 800),
#  (987, u'Berkeley', u'CS', u'Y', 876, u'Irene', 3.9, 400),
#  (987, u'Berkeley', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (876, u'Stanford', u'CS', u'N', 123, u'Amy', 3.9, 1000),
#  (876, u'Stanford', u'CS', u'N', 234, u'Bob', 3.6, 1500),
#  (876, u'Stanford', u'CS', u'N', 345, u'Craig', 3.5, 500),
#  (876, u'Stanford', u'CS', u'N', 456, u'Doris', 3.9, 1000),
#  (876, u'Stanford', u'CS', u'N', 543, u'Craig', 3.4, 2000),
#  (876, u'Stanford', u'CS', u'N', 567, u'Edward', 2.9, 2000),
#  (876, u'Stanford', u'CS', u'N', 654, u'Amy', 3.9, 1000),
#  (876, u'Stanford', u'CS', u'N', 678, u'Fay', 3.8, 200),
#  (876, u'Stanford', u'CS', u'N', 765, u'Jay', 2.9, 1500),
#  (876, u'Stanford', u'CS', u'N', 789, u'Gary', 3.4, 800),
#  (876, u'Stanford', u'CS', u'N', 876, u'Irene', 3.9, 400),
#  (876, u'Stanford', u'CS', u'N', 987, u'Helen', 3.7, 800),
#  (876, u'MIT', u'biology', u'Y', 123, u'Amy', 3.9, 1000),
#  (876, u'MIT', u'biology', u'Y', 234, u'Bob', 3.6, 1500),
#  (876, u'MIT', u'biology', u'Y', 345, u'Craig', 3.5, 500),
#  (876, u'MIT', u'biology', u'Y', 456, u'Doris', 3.9, 1000),
#  (876, u'MIT', u'biology', u'Y', 543, u'Craig', 3.4, 2000),
#  (876, u'MIT', u'biology', u'Y', 567, u'Edward', 2.9, 2000),
#  (876, u'MIT', u'biology', u'Y', 654, u'Amy', 3.9, 1000),
#  (876, u'MIT', u'biology', u'Y', 678, u'Fay', 3.8, 200),
#  (876, u'MIT', u'biology', u'Y', 765, u'Jay', 2.9, 1500),
#  (876, u'MIT', u'biology', u'Y', 789, u'Gary', 3.4, 800),
#  (876, u'MIT', u'biology', u'Y', 876, u'Irene', 3.9, 400),
#  (876, u'MIT', u'biology', u'Y', 987, u'Helen', 3.7, 800),
#  (876, u'MIT', u'marine biology', u'N', 123, u'Amy', 3.9, 1000),
#  (876, u'MIT', u'marine biology', u'N', 234, u'Bob', 3.6, 1500),
#  (876, u'MIT', u'marine biology', u'N', 345, u'Craig', 3.5, 500),
#  (876, u'MIT', u'marine biology', u'N', 456, u'Doris', 3.9, 1000),
#  (876, u'MIT', u'marine biology', u'N', 543, u'Craig', 3.4, 2000),
#  (876, u'MIT', u'marine biology', u'N', 567, u'Edward', 2.9, 2000),
#  (876, u'MIT', u'marine biology', u'N', 654, u'Amy', 3.9, 1000),
#  (876, u'MIT', u'marine biology', u'N', 678, u'Fay', 3.8, 200),
#  (876, u'MIT', u'marine biology', u'N', 765, u'Jay', 2.9, 1500),
#  (876, u'MIT', u'marine biology', u'N', 789, u'Gary', 3.4, 800),
#  (876, u'MIT', u'marine biology', u'N', 876, u'Irene', 3.9, 400),
#  (876, u'MIT', u'marine biology', u'N', 987, u'Helen', 3.7, 800),
#  (765, u'Stanford', u'history', u'Y', 123, u'Amy', 3.9, 1000),
#  (765, u'Stanford', u'history', u'Y', 234, u'Bob', 3.6, 1500),
#  (765, u'Stanford', u'history', u'Y', 345, u'Craig', 3.5, 500),
#  (765, u'Stanford', u'history', u'Y', 456, u'Doris', 3.9, 1000),
#  (765, u'Stanford', u'history', u'Y', 543, u'Craig', 3.4, 2000),
#  (765, u'Stanford', u'history', u'Y', 567, u'Edward', 2.9, 2000),
#  (765, u'Stanford', u'history', u'Y', 654, u'Amy', 3.9, 1000),
#  (765, u'Stanford', u'history', u'Y', 678, u'Fay', 3.8, 200),
#  (765, u'Stanford', u'history', u'Y', 765, u'Jay', 2.9, 1500),
#  (765, u'Stanford', u'history', u'Y', 789, u'Gary', 3.4, 800),
#  (765, u'Stanford', u'history', u'Y', 876, u'Irene', 3.9, 400),
#  (765, u'Stanford', u'history', u'Y', 987, u'Helen', 3.7, 800),
#  (765, u'Cornell', u'history', u'N', 123, u'Amy', 3.9, 1000),
#  (765, u'Cornell', u'history', u'N', 234, u'Bob', 3.6, 1500),
#  (765, u'Cornell', u'history', u'N', 345, u'Craig', 3.5, 500),
#  (765, u'Cornell', u'history', u'N', 456, u'Doris', 3.9, 1000),
#  (765, u'Cornell', u'history', u'N', 543, u'Craig', 3.4, 2000),
#  (765, u'Cornell', u'history', u'N', 567, u'Edward', 2.9, 2000),
#  (765, u'Cornell', u'history', u'N', 654, u'Amy', 3.9, 1000),
#  (765, u'Cornell', u'history', u'N', 678, u'Fay', 3.8, 200),
#  (765, u'Cornell', u'history', u'N', 765, u'Jay', 2.9, 1500),
#  (765, u'Cornell', u'history', u'N', 789, u'Gary', 3.4, 800),
#  (765, u'Cornell', u'history', u'N', 876, u'Irene', 3.9, 400),
#  (765, u'Cornell', u'history', u'N', 987, u'Helen', 3.7, 800),
#  (765, u'Cornell', u'psychology', u'Y', 123, u'Amy', 3.9, 1000),
#  (765, u'Cornell', u'psychology', u'Y', 234, u'Bob', 3.6, 1500),
#  (765, u'Cornell', u'psychology', u'Y', 345, u'Craig', 3.5, 500),
#  (765, u'Cornell', u'psychology', u'Y', 456, u'Doris', 3.9, 1000),
#  (765, u'Cornell', u'psychology', u'Y', 543, u'Craig', 3.4, 2000),
#  (765, u'Cornell', u'psychology', u'Y', 567, u'Edward', 2.9, 2000),
#  (765, u'Cornell', u'psychology', u'Y', 654, u'Amy', 3.9, 1000),
#  (765, u'Cornell', u'psychology', u'Y', 678, u'Fay', 3.8, 200),
#  (765, u'Cornell', u'psychology', u'Y', 765, u'Jay', 2.9, 1500),
#  (765, u'Cornell', u'psychology', u'Y', 789, u'Gary', 3.4, 800),
#  (765, u'Cornell', u'psychology', u'Y', 876, u'Irene', 3.9, 400),
#  (765, u'Cornell', u'psychology', u'Y', 987, u'Helen', 3.7, 800),
#  (543, u'MIT', u'CS', u'N', 123, u'Amy', 3.9, 1000),
#  (543, u'MIT', u'CS', u'N', 234, u'Bob', 3.6, 1500),
#  (543, u'MIT', u'CS', u'N', 345, u'Craig', 3.5, 500),
#  (543, u'MIT', u'CS', u'N', 456, u'Doris', 3.9, 1000),
#  (543, u'MIT', u'CS', u'N', 543, u'Craig', 3.4, 2000),
#  (543, u'MIT', u'CS', u'N', 567, u'Edward', 2.9, 2000),
#  (543, u'MIT', u'CS', u'N', 654, u'Amy', 3.9, 1000),
#  (543, u'MIT', u'CS', u'N', 678, u'Fay', 3.8, 200),
#  (543, u'MIT', u'CS', u'N', 765, u'Jay', 2.9, 1500),
#  (543, u'MIT', u'CS', u'N', 789, u'Gary', 3.4, 800),
#  (543, u'MIT', u'CS', u'N', 876, u'Irene', 3.9, 400),
#  (543, u'MIT', u'CS', u'N', 987, u'Helen', 3.7, 800),
#  (321, u'MIT', u'history', u'N', 123, u'Amy', 3.9, 1000),
#  (321, u'MIT', u'history', u'N', 234, u'Bob', 3.6, 1500),
#  (321, u'MIT', u'history', u'N', 345, u'Craig', 3.5, 500),
#  (321, u'MIT', u'history', u'N', 456, u'Doris', 3.9, 1000),
#  (321, u'MIT', u'history', u'N', 543, u'Craig', 3.4, 2000),
#  (321, u'MIT', u'history', u'N', 567, u'Edward', 2.9, 2000),
#  (321, u'MIT', u'history', u'N', 654, u'Amy', 3.9, 1000),
#  (321, u'MIT', u'history', u'N', 678, u'Fay', 3.8, 200),
#  (321, u'MIT', u'history', u'N', 765, u'Jay', 2.9, 1500),
#  (321, u'MIT', u'history', u'N', 789, u'Gary', 3.4, 800),
#  (321, u'MIT', u'history', u'N', 876, u'Irene', 3.9, 400),
#  (321, u'MIT', u'history', u'N', 987, u'Helen', 3.7, 800),
#  (321, u'MIT', u'psychology', u'N', 123, u'Amy', 3.9, 1000),
#  (321, u'MIT', u'psychology', u'N', 234, u'Bob', 3.6, 1500),
#  (321, u'MIT', u'psychology', u'N', 345, u'Craig', 3.5, 500),
#  (321, u'MIT', u'psychology', u'N', 456, u'Doris', 3.9, 1000),
#  (321, u'MIT', u'psychology', u'N', 543, u'Craig', 3.4, 2000),
#  (321, u'MIT', u'psychology', u'N', 567, u'Edward', 2.9, 2000),
#  (321, u'MIT', u'psychology', u'N', 654, u'Amy', 3.9, 1000),
#  (321, u'MIT', u'psychology', u'N', 678, u'Fay', 3.8, 200),
#  (321, u'MIT', u'psychology', u'N', 765, u'Jay', 2.9, 1500),
#  (321, u'MIT', u'psychology', u'N', 789, u'Gary', 3.4, 800),
#  (321, u'MIT', u'psychology', u'N', 876, u'Irene', 3.9, 400),
#  (321, u'MIT', u'psychology', u'N', 987, u'Helen', 3.7, 800)]

# %% [markdown]
# The number of rows in this table is the product of the
# number of rows in each table, and most of the rows in the
# combined table are totally uninteresting, since the `s_id`'s
# doesn't have anything to do with each other (e.g., in one
# line the fact that a student with `s_id` 123 has applied to
# CS at Stanford is combined with the fact that there is a
# student Bob with `s_id` 234 who has a `gpa` of 3.6).
#
# The only rows of interest to us are those where the student
# id from the `applications` table is the same as the student
# id from the `students` table, and we can express that as:

# %%
# %%sql
# SELECT      *
# FROM        applications
# CROSS JOIN  students
# WHERE       applications.s_id = students.s_id
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Stanford', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (123, u'Stanford', u'EE', u'N', 123, u'Amy', 3.9, 1000),
#  (123, u'Berkeley', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (123, u'Cornell', u'EE', u'Y', 123, u'Amy', 3.9, 1000),
#  (234, u'Berkeley', u'biology', u'N', 234, u'Bob', 3.6, 1500),
#  (345, u'MIT', u'bioengineering', u'Y', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'bioengineering', u'N', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'CS', u'Y', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'EE', u'N', 345, u'Craig', 3.5, 500),
#  (678, u'Stanford', u'history', u'Y', 678, u'Fay', 3.8, 200),
#  (987, u'Stanford', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (987, u'Berkeley', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (876, u'Stanford', u'CS', u'N', 876, u'Irene', 3.9, 400),
#  (876, u'MIT', u'biology', u'Y', 876, u'Irene', 3.9, 400),
#  (876, u'MIT', u'marine biology', u'N', 876, u'Irene', 3.9, 400),
#  (765, u'Stanford', u'history', u'Y', 765, u'Jay', 2.9, 1500),
#  (765, u'Cornell', u'history', u'N', 765, u'Jay', 2.9, 1500),
#  (765, u'Cornell', u'psychology', u'Y', 765, u'Jay', 2.9, 1500),
#  (543, u'MIT', u'CS', u'N', 543, u'Craig', 3.4, 2000)]

# %% [markdown]
# or, using aliases, so we don't have to write long table
# names:

# %%
# %%sql
# SELECT      *
# FROM        applications AS a
# CROSS JOIN  students AS s
# WHERE       a.s_id = s.s_id
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Stanford', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (123, u'Stanford', u'EE', u'N', 123, u'Amy', 3.9, 1000),
#  (123, u'Berkeley', u'CS', u'Y', 123, u'Amy', 3.9, 1000),
#  (123, u'Cornell', u'EE', u'Y', 123, u'Amy', 3.9, 1000),
#  (234, u'Berkeley', u'biology', u'N', 234, u'Bob', 3.6, 1500),
#  (345, u'MIT', u'bioengineering', u'Y', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'bioengineering', u'N', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'CS', u'Y', 345, u'Craig', 3.5, 500),
#  (345, u'Cornell', u'EE', u'N', 345, u'Craig', 3.5, 500),
#  (678, u'Stanford', u'history', u'Y', 678, u'Fay', 3.8, 200),
#  (987, u'Stanford', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (987, u'Berkeley', u'CS', u'Y', 987, u'Helen', 3.7, 800),
#  (876, u'Stanford', u'CS', u'N', 876, u'Irene', 3.9, 400),
#  (876, u'MIT', u'biology', u'Y', 876, u'Irene', 3.9, 400),
#  (876, u'MIT', u'marine biology', u'N', 876, u'Irene', 3.9, 400),
#  (765, u'Stanford', u'history', u'Y', 765, u'Jay', 2.9, 1500),
#  (765, u'Cornell', u'history', u'N', 765, u'Jay', 2.9, 1500),
#  (765, u'Cornell', u'psychology', u'Y', 765, u'Jay', 2.9, 1500),
#  (543, u'MIT', u'CS', u'N', 543, u'Craig', 3.4, 2000)]

# %% [markdown]
# We can clean up the output using a projection:

# %%
# %%sql
# SELECT      s.s_name, a.c_name, a.major
# FROM        applications AS a
# CROSS JOIN  students AS s
# WHERE       a.s_id = s.s_id
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', u'Berkeley', u'CS'),
#  (u'Amy', u'Cornell', u'EE'),
#  (u'Amy', u'Stanford', u'CS'),
#  (u'Amy', u'Stanford', u'EE'),
#  (u'Bob', u'Berkeley', u'biology'),
#  (u'Craig', u'Cornell', u'CS'),
#  (u'Craig', u'Cornell', u'EE'),
#  (u'Craig', u'Cornell', u'bioengineering'),
#  (u'Craig', u'MIT', u'bioengineering'),
#  (u'Craig', u'MIT', u'CS'),
#  (u'Fay', u'Stanford', u'history'),
#  (u'Jay', u'Cornell', u'history'),
#  (u'Jay', u'Cornell', u'psychology'),
#  (u'Jay', u'Stanford', u'history'),
#  (u'Irene', u'MIT', u'biology'),
#  (u'Irene', u'MIT', u'marine biology'),
#  (u'Irene', u'Stanford', u'CS'),
#  (u'Helen', u'Berkeley', u'CS'),
#  (u'Helen', u'Stanford', u'CS')]

# %% [markdown]
# or even

# %%
# %%sql
# SELECT      s_name AS name, c_name AS college, major
# FROM        applications AS a
# CROSS JOIN  students AS s
# WHERE       a.s_id = s.s_id
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', u'Berkeley', u'CS'),
#  (u'Amy', u'Cornell', u'EE'),
#  (u'Amy', u'Stanford', u'CS'),
#  (u'Amy', u'Stanford', u'EE'),
#  (u'Bob', u'Berkeley', u'biology'),
#  (u'Craig', u'Cornell', u'CS'),
#  (u'Craig', u'Cornell', u'EE'),
#  (u'Craig', u'Cornell', u'bioengineering'),
#  (u'Craig', u'MIT', u'bioengineering'),
#  (u'Craig', u'MIT', u'CS'),
#  (u'Fay', u'Stanford', u'history'),
#  (u'Jay', u'Cornell', u'history'),
#  (u'Jay', u'Cornell', u'psychology'),
#  (u'Jay', u'Stanford', u'history'),
#  (u'Irene', u'MIT', u'biology'),
#  (u'Irene', u'MIT', u'marine biology'),
#  (u'Irene', u'Stanford', u'CS'),
#  (u'Helen', u'Berkeley', u'CS'),
#  (u'Helen', u'Stanford', u'CS')]

# %% [markdown]
# (we only need to prefix column names when there would
# otherwise be an ambiguity).
#
# There is a shortcut for cross joins, we can just put a comma
# between the two tables we want to join:

# %%
# %%sql
# SELECT s_name AS name, c_name AS college, major
# FROM   applications AS a, students AS s
# WHERE  a.s_id = s.s_id
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', u'Berkeley', u'CS'),
#  (u'Amy', u'Cornell', u'EE'),
#  (u'Amy', u'Stanford', u'CS'),
#  (u'Amy', u'Stanford', u'EE'),
#  (u'Bob', u'Berkeley', u'biology'),
#  (u'Craig', u'Cornell', u'CS'),
#  (u'Craig', u'Cornell', u'EE'),
#  (u'Craig', u'Cornell', u'bioengineering'),
#  (u'Craig', u'MIT', u'bioengineering'),
#  (u'Craig', u'MIT', u'CS'),
#  (u'Fay', u'Stanford', u'history'),
#  (u'Jay', u'Cornell', u'history'),
#  (u'Jay', u'Cornell', u'psychology'),
#  (u'Jay', u'Stanford', u'history'),
#  (u'Irene', u'MIT', u'biology'),
#  (u'Irene', u'MIT', u'marine biology'),
#  (u'Irene', u'Stanford', u'CS'),
#  (u'Helen', u'Berkeley', u'CS'),
#  (u'Helen', u'Stanford', u'CS')]

# %% [markdown]
# This works, but there are much more elegant ways to write
# this query.
#
# An _inner join_ combine two tables into a new table (it's
# not actually saved as a table) -- it does this by creating
# combined rows only when rows from the two tables 'match'
# each other. In this case it's the `s_id` columns which
# should match, so we write:

# %%
# %%sql
# SELECT      s_name AS name, c_name AS college, major
# FROM        applications AS a
# INNER JOIN  students AS s
# ON          a.s_id = s.s_id

# %% [markdown]
# Logically it can be seen as the equivalent of a cross join
# and then a selection, but the database engine normally use
# algorithms which are much faster and requires much less
# memory when we define an inner join. Once you get used to
# them, inner joins will feel much better to use than cross
# joins (although, in theory, the database should try to
# optimize all queries, and _might_ find an efficient way to
# execute even cross joins).
#
# Inner joins are the default joins, so we can omit the word
# `INNER`, and just write `JOIN`:

# %%
# %%sql
# SELECT  s_name AS name, c_name AS college, major
# FROM    applications AS a
# JOIN    students AS s
# ON      a.s_id = s.s_id

# %% [markdown]
# The condition on which we join tables is often called the
# _join predicate_, and a join where the join predicate is an
# equality test, such as here, is sometimes called an
# _equi-join_. There is a special form of join when the
# columns we're comparing in an equi-join have the same name:

# %%
# %%sql
# SELECT  s_name AS name, c_name AS college, major
# FROM    applications
# JOIN    students
# USING   (s_id)

# %% [markdown]
# One benefit from using `USING` is that the columns we join
# over will not be duplicated, we get only one of them in the
# output.
#
# I'd say this is the preferred way of writing this query.
#
# There is an even simpler way to write it, using what's
# called a _natural join_, but it's error-prone, and you're
# recommended not to use it. It's written as

# %%
# %%sql
# SELECT        s_name AS name, c_name AS college, major
# FROM          applications
# NATURAL JOIN  students
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', u'Berkeley', u'CS'),
#  (u'Amy', u'Cornell', u'EE'),
#  (u'Amy', u'Stanford', u'CS'),
#  (u'Amy', u'Stanford', u'EE'),
#  (u'Bob', u'Berkeley', u'biology'),
#  (u'Craig', u'Cornell', u'CS'),
#  (u'Craig', u'Cornell', u'EE'),
#  (u'Craig', u'Cornell', u'bioengineering'),
#  (u'Craig', u'MIT', u'bioengineering'),
#  (u'Craig', u'MIT', u'CS'),
#  (u'Fay', u'Stanford', u'history'),
#  (u'Jay', u'Cornell', u'history'),
#  (u'Jay', u'Cornell', u'psychology'),
#  (u'Jay', u'Stanford', u'history'),
#  (u'Irene', u'MIT', u'biology'),
#  (u'Irene', u'MIT', u'marine biology'),
#  (u'Irene', u'Stanford', u'CS'),
#  (u'Helen', u'Berkeley', u'CS'),
#  (u'Helen', u'Stanford', u'CS')]

# %% [markdown]
# and it joins the tables using an equi-join for all columns
# with coinciding names -- _this could create big problems if
# there are attributes in the tables which just happen to
# coincide without us realizing it!_ If we use the `JOIN` ...
# `USING` instead, we explicitly declare on which attributes
# to join, so we guard ourselves against accidental column
# name collisions.
#
# Observe that we can use selections just as before when we
# join tables.
#
# **Exercise:** _Write a SQL query which shows all applications as
# above, but only for students applying for CS at Stanford._

# %%
# %%sql
#
# SELECT s_name AS name, s_id
# FROM applications
# JOIN students
# USING (s_id)
# JOIN colleges
# USING (c_name)
# WHERE state is 'CA' and major is 'CS'
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', 123),
#  (u'Amy', 123),
#  (u'Irene', 876),
#  (u'Helen', 987),
#  (u'Helen', 987)]

# %% [markdown]
# **Exercise:** _Write a SQL query which shows all applications
# as above, but also shows what state the college is in._

# %%
# %%sql
#
# SELECT s_name AS name, c_name, state, major
# FROM applications
# JOIN students
# USING (s_id)
# JOIN colleges
# USING (c_name)
# WHERE state is 'CA' AND major is 'CS'
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', u'Berkeley', u'CA', u'CS'),
#  (u'Amy', u'Stanford', u'CA', u'CS'),
#  (u'Irene', u'Stanford', u'CA', u'CS'),
#  (u'Helen', u'Berkeley', u'CA', u'CS'),
#  (u'Helen', u'Stanford', u'CA', u'CS')]

# %% [markdown]
# We can join a table with itself, write a query which finds
# all pairs with the same Grade Point Average (GPA):
#
# We can do it either with a cross join:

# %%
# %%sql
# SELECT s1.s_id, s1.s_name, s1.gpa, s2.s_id, s2.s_name, s2.gpa
# FROM   students AS s1, students AS s2
# WHERE  s1.gpa = s2.gpa AND
#        s1.s_id < s2.s_id
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Amy', 3.9, 654, u'Amy', 3.9),
#  (123, u'Amy', 3.9, 456, u'Doris', 3.9),
#  (123, u'Amy', 3.9, 876, u'Irene', 3.9),
#  (456, u'Doris', 3.9, 654, u'Amy', 3.9),
#  (456, u'Doris', 3.9, 876, u'Irene', 3.9),
#  (543, u'Craig', 3.4, 789, u'Gary', 3.4),
#  (567, u'Edward', 2.9, 765, u'Jay', 2.9),
#  (654, u'Amy', 3.9, 876, u'Irene', 3.9)]

# %% [markdown]
# or with an inner join:

# %%
# %%sql
# SELECT s1.s_id, s1.s_name, s2.s_id, s2.s_name, gpa
# FROM   students AS s1
# JOIN   students AS s2
# USING  (gpa)
# WHERE  s1.s_id < s2.s_id

# %% [markdown]
# Joining a table with itself is called a _self join_.
#
# **Exercise:** Show the student names, college names, and
# majors for all applications to Stanford:

# %%
# %%sql
# SELECT s_name, c_name, major
# FROM applications
# JOIN students
# USING (s_id)
# WHERE c_name is 'Stanford'
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', u'Stanford', u'CS'),
#  (u'Amy', u'Stanford', u'EE'),
#  (u'Fay', u'Stanford', u'history'),
#  (u'Jay', u'Stanford', u'history'),
#  (u'Irene', u'Stanford', u'CS'),
#  (u'Helen', u'Stanford', u'CS')]

# %% [markdown]
# **Exercise:** Show the average `size_hs` for applications to
# the different colleges, order by descending size:

# %%
# %%sql
# SELECT c_name, avg(size_hs)
# FROM applications
# JOIN students
# USING (s_id)
# GROUP BY c_name
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Berkeley', 1100.0),
#  (u'Cornell', 916.6666666666666),
#  (u'MIT', 825.0),
#  (u'Stanford', 816.6666666666666)]

# %% [markdown]
# We can apply joins in several steps, each time combining
# what we've previously joined with another table (the result
# of which is a new table, which can be joined over and over
# again...).
#
#
# **Exercise:** _Show the names of all students who have
# applied for a college in California -- also show the college
# and major._

# %%
# %%sql
#
# SELECT s_name, c_name, major, state
# FROM applications
# JOIN students
# USING(s_id)
# JOIN colleges
# USING (c_name)
# WHERE state is 'CA'
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', u'Berkeley', u'CS', u'CA'),
#  (u'Amy', u'Stanford', u'CS', u'CA'),
#  (u'Amy', u'Stanford', u'EE', u'CA'),
#  (u'Bob', u'Berkeley', u'biology', u'CA'),
#  (u'Fay', u'Stanford', u'history', u'CA'),
#  (u'Jay', u'Stanford', u'history', u'CA'),
#  (u'Irene', u'Stanford', u'CS', u'CA'),
#  (u'Helen', u'Berkeley', u'CS', u'CA'),
#  (u'Helen', u'Stanford', u'CS', u'CA')]

# %% [markdown]
# In lab 1 you'll get plenty of exercise in joining.
#
#
# ## Outer joins
#
# An inner join combines rows in different tables _when there
# is a match in the other table_, rows with no corresponding
# row in the other table will not turn up in the joined table.
#
# With an _outer join_ we can make sure that every row in one
# or both of the tables turn up in the joined table -- in case
# there is no match, it will be paired with a row containing
# unly `NULL` values (`NULL` is written as `None` in our
# notebooks).
#
# As as example, we've seen how to join students and their
# applications:
#
# <!---
# SELECT s_name, s_id, c_name, major
# FROM   students
# JOIN   applications
# USING  (s_id)
# -->

# %%
# %%sql
#
# SELECT *
# FROM students
# JOIN applications
# USING (s_id)
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Amy', 3.9, 1000, u'Stanford', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'EE', u'N'),
#  (123, u'Amy', 3.9, 1000, u'Berkeley', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Cornell', u'EE', u'Y'),
#  (234, u'Bob', 3.6, 1500, u'Berkeley', u'biology', u'N'),
#  (345, u'Craig', 3.5, 500, u'MIT', u'bioengineering', u'Y'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'bioengineering', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'CS', u'Y'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'EE', u'N'),
#  (678, u'Fay', 3.8, 200, u'Stanford', u'history', u'Y'),
#  (987, u'Helen', 3.7, 800, u'Stanford', u'CS', u'Y'),
#  (987, u'Helen', 3.7, 800, u'Berkeley', u'CS', u'Y'),
#  (876, u'Irene', 3.9, 400, u'Stanford', u'CS', u'N'),
#  (876, u'Irene', 3.9, 400, u'MIT', u'biology', u'Y'),
#  (876, u'Irene', 3.9, 400, u'MIT', u'marine biology', u'N'),
#  (765, u'Jay', 2.9, 1500, u'Stanford', u'history', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'history', u'N'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'psychology', u'Y'),
#  (543, u'Craig', 3.4, 2000, u'MIT', u'CS', u'N')]

# %% [markdown]
# Now, assume we also want to see those students who haven't
# applied, we can do that using a _left outer join_:
#
# <!---
# SELECT          s_name, s_id, c_name, major
# FROM            students
# LEFT OUTER JOIN applications
# USING           (s_id)
# -->

# %%
# %%sql
#
# SELECT *
# FROM students
# LEFT OUTER JOIN applications
# USING (s_id)
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Amy', 3.9, 1000, u'Berkeley', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Cornell', u'EE', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'EE', u'N'),
#  (234, u'Bob', 3.6, 1500, u'Berkeley', u'biology', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'CS', u'Y'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'EE', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'bioengineering', u'N'),
#  (345, u'Craig', 3.5, 500, u'MIT', u'bioengineering', u'Y'),
#  (456, u'Doris', 3.9, 1000, None, None, None),
#  (543, u'Craig', 3.4, 2000, u'MIT', u'CS', u'N'),
#  (567, u'Edward', 2.9, 2000, None, None, None),
#  (654, u'Amy', 3.9, 1000, None, None, None),
#  (678, u'Fay', 3.8, 200, u'Stanford', u'history', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'history', u'N'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'psychology', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Stanford', u'history', u'Y'),
#  (789, u'Gary', 3.4, 800, None, None, None),
#  (876, u'Irene', 3.9, 400, u'MIT', u'biology', u'Y'),
#  (876, u'Irene', 3.9, 400, u'MIT', u'marine biology', u'N'),
#  (876, u'Irene', 3.9, 400, u'Stanford', u'CS', u'N'),
#  (987, u'Helen', 3.7, 800, u'Berkeley', u'CS', u'Y'),
#  (987, u'Helen', 3.7, 800, u'Stanford', u'CS', u'Y')]

# %% [markdown]
# We still get the rows we got before, but now we also get
# rows with `NULL`'s in the attributes from the right
# relation, if there is no row in the right table which
# corresponds to a row in the left table (i.e., the `s_id`
# found in the `students` table has no match in the
# `applications` table -- the tuples on the left are sometimes
# called _dangling tuples_).
#
# By the way, we can omit the `OUTER` keyword:
#
# <!---
# SELECT    s_name, s_id, c_name, major
# FROM      students
# LEFT JOIN applications
# USING     (s_id)
# -->

# %%
# %%sql
#
# SELECT *
# FROM students
# LEFT JOIN applications
# USING (s_id)
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Amy', 3.9, 1000, u'Berkeley', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Cornell', u'EE', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'EE', u'N'),
#  (234, u'Bob', 3.6, 1500, u'Berkeley', u'biology', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'CS', u'Y'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'EE', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'bioengineering', u'N'),
#  (345, u'Craig', 3.5, 500, u'MIT', u'bioengineering', u'Y'),
#  (456, u'Doris', 3.9, 1000, None, None, None),
#  (543, u'Craig', 3.4, 2000, u'MIT', u'CS', u'N'),
#  (567, u'Edward', 2.9, 2000, None, None, None),
#  (654, u'Amy', 3.9, 1000, None, None, None),
#  (678, u'Fay', 3.8, 200, u'Stanford', u'history', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'history', u'N'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'psychology', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Stanford', u'history', u'Y'),
#  (789, u'Gary', 3.4, 800, None, None, None),
#  (876, u'Irene', 3.9, 400, u'MIT', u'biology', u'Y'),
#  (876, u'Irene', 3.9, 400, u'MIT', u'marine biology', u'N'),
#  (876, u'Irene', 3.9, 400, u'Stanford', u'CS', u'N'),
#  (987, u'Helen', 3.7, 800, u'Berkeley', u'CS', u'Y'),
#  (987, u'Helen', 3.7, 800, u'Stanford', u'CS', u'Y')]

# %% [markdown]
# There is a 'natural' version of outer joins ...
#
# <!---
# SELECT            s_name, s_id, c_name, major
# FROM              students
# NATURAL LEFT JOIN applications
# -->

# %%
# %%sql
#
# SELECT *
# FROM students
# NATURAL LEFT JOIN applications
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(123, u'Amy', 3.9, 1000, u'Berkeley', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Cornell', u'EE', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'CS', u'Y'),
#  (123, u'Amy', 3.9, 1000, u'Stanford', u'EE', u'N'),
#  (234, u'Bob', 3.6, 1500, u'Berkeley', u'biology', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'CS', u'Y'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'EE', u'N'),
#  (345, u'Craig', 3.5, 500, u'Cornell', u'bioengineering', u'N'),
#  (345, u'Craig', 3.5, 500, u'MIT', u'bioengineering', u'Y'),
#  (456, u'Doris', 3.9, 1000, None, None, None),
#  (543, u'Craig', 3.4, 2000, u'MIT', u'CS', u'N'),
#  (567, u'Edward', 2.9, 2000, None, None, None),
#  (654, u'Amy', 3.9, 1000, None, None, None),
#  (678, u'Fay', 3.8, 200, u'Stanford', u'history', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'history', u'N'),
#  (765, u'Jay', 2.9, 1500, u'Cornell', u'psychology', u'Y'),
#  (765, u'Jay', 2.9, 1500, u'Stanford', u'history', u'Y'),
#  (789, u'Gary', 3.4, 800, None, None, None),
#  (876, u'Irene', 3.9, 400, u'MIT', u'biology', u'Y'),
#  (876, u'Irene', 3.9, 400, u'MIT', u'marine biology', u'N'),
#  (876, u'Irene', 3.9, 400, u'Stanford', u'CS', u'N'),
#  (987, u'Helen', 3.7, 800, u'Berkeley', u'CS', u'Y'),
#  (987, u'Helen', 3.7, 800, u'Stanford', u'CS', u'Y')]

# %% [markdown]
# ... but for the same reasons as for inner joins, it's
# _much_, _much_ better to explicitly declare which attribute
# we're joining (using `USING`).
#
# There is a way to get the same result without inner or outer
# joins, but it requires more code:

# %%
# %%sql
# SELECT      s_name, s.s_id, c_name, major
# FROM        students s
# CROSS JOIN  applications a
# WHERE       s.s_id = a.s_id
# UNION
# SELECT      s_name, s_id, NULL, NULL
# FROM        students
# WHERE       s_id NOT IN (SELECT s_id
#                          FROM   applications)

# %% [markdown]
# Seing this might help you understand what left outer join
# actually returns.
#
# Now, the opposite problem, we want to see applications with
# no matching students -- of course we could just swap
# `students` and `applications` in the query above, but we
# could also use a _right outer join_:

# %%
# %%sql
# SELECT     s_name, s_id, c_name, major
# FROM       applications
# LEFT JOIN students USING (s_id)
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Amy', 123, u'Berkeley', u'CS'),
#  (u'Amy', 123, u'Cornell', u'EE'),
#  (u'Amy', 123, u'Stanford', u'CS'),
#  (u'Amy', 123, u'Stanford', u'EE'),
#  (u'Bob', 234, u'Berkeley', u'biology'),
#  (None, 321, u'MIT', u'history'),
#  (None, 321, u'MIT', u'psychology'),
#  (u'Craig', 345, u'Cornell', u'CS'),
#  (u'Craig', 345, u'Cornell', u'EE'),
#  (u'Craig', 345, u'Cornell', u'bioengineering'),
#  (u'Craig', 345, u'MIT', u'bioengineering'),
#  (u'Craig', 543, u'MIT', u'CS'),
#  (u'Fay', 678, u'Stanford', u'history'),
#  (u'Jay', 765, u'Cornell', u'history'),
#  (u'Jay', 765, u'Cornell', u'psychology'),
#  (u'Jay', 765, u'Stanford', u'history'),
#  (u'Irene', 876, u'MIT', u'biology'),
#  (u'Irene', 876, u'MIT', u'marine biology'),
#  (u'Irene', 876, u'Stanford', u'CS'),
#  (u'Helen', 987, u'Berkeley', u'CS'),
#  (u'Helen', 987, u'Stanford', u'CS')]

# %% [markdown]
# Right outer joins are not supported in SQLite (yet), though.
#
# There is also a _full outer join_, which combines the left-
# and the right outer joins:

# %%
# %%sql
# SELECT    s_name, s_id, c_name, major
# FROM      students
# FULL JOIN applications USING (s_id)
# Out:
#  * sqlite:///lect02.sqlite
# (sqlite3.OperationalError) RIGHT and FULL OUTER JOINs are not currently supported
# [SQL: SELECT    s_name, s_id, c_name, major
# FROM      students
# FULL JOIN applications USING (s_id)]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# Of the outer joins, SQLite only supports left outer, the
# other ones are left out :-).
#
# **Exercise:** _Find all 'spurious' applications, i.e.,
# applications where the student id doesn't match any
# student's id._ Try to solve this exercise in two ways (one
# using an outer join, the other using subqueries).

# %%
# %%sql
# SELECT c_name, s_id, major
# FROM applications
# LEFT OUTER JOIN students
# USING (s_id)
# WHERE s_name is  NULL
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'MIT', 321, u'history'), (u'MIT', 321, u'psychology')]

# %%
# %%sql
# SELECT c_name, s_id, major
# FROM applications
# WHERE s_id NOT IN (
#     SELECT s_id
#     FROM students
# )
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'MIT', 321, u'history'), (u'MIT', 321, u'psychology')]

# %% [markdown]
# **Exercise:** _Generate the unwieldly college application
# table we started out with above from the three smaller
# tables._

# %%
# %%sql

# %% [markdown]
# ## Back to the olympics:
#
# Last time we had a few queries using our old `olympics`
# table, let's revisit one of them using `better_olympics` and
# `continents` instead. First we rename our `olympics` and
# `better_olympics` tables, to make things easier:

# %%
# %%sql
# ALTER TABLE olympics
# RENAME TO   bad_olympics;
#
# ALTER TABLE better_olympics
# RENAME TO   olympics;
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# Done.
# []

# %% [markdown]
# **Q:** _How many olympic games has each continent hosted?_

# %%
# %%sql
# SELECT continent, count()
# FROM olympics
# JOIN continents
# USING (country)
# GROUP BY continent
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Asia', 6),
#  (u'Australia', 2),
#  (u'Europe', 31),
#  (u'North America', 12),
#  (u'South America', 1)]

# %% [markdown]
# **Q:** _When was the first and the latest olympic games in
# each continent?_

# %%
# %%sql
# SELECT continent, min(year) first, max(year) last
# FROM olympics
# JOIN continents
# USING (country)
# GROUP BY continent
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(u'Asia', 1964, 2018),
#  (u'Australia', 1956, 2000),
#  (u'Europe', 1896, 2014),
#  (u'North America', 1904, 2010),
#  (u'South America', 2016, 2016)]

# %% [markdown]
# **Q:** _Recreate the original `olympics` table from the
# improved `olympics` and `continents`._

# %%
# %%sql
#
# SELECT *
# FROM olympics
# JOIN continents
# USING (country)
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(1924, u'Chamonix', u'France', u'winter', u'I', u'Europe'),
#  (1928, u'St. Moritz', u'Switzerland', u'winter', u'II', u'Europe'),
#  (1932, u'Lake Placid', u'United States', u'winter', u'III', u'North America'),
#  (1936, u'Garmisch-Partenkirchen', u'Germany', u'winter', u'IV', u'Europe'),
#  (1948, u'St. Moritz', u' Switzerland', u'winter', u'V', u'Europe'),
#  (1952, u'Oslo', u'Norway', u'winter', u'VI', u'Europe'),
#  (1956, u"Cortina d'Ampezzo", u'Italy', u'winter', u'VII', u'Europe'),
#  (1960, u'Squaw Valley', u'United States', u'winter', u'VIII', u'North America'),
#  (1964, u'Innsbruck', u'Austria', u'winter', u'IX', u'Europe'),
#  (1968, u'Grenoble', u'France', u'winter', u'X', u'Europe'),
#  (1972, u'Sapporo', u'Japan', u'winter', u'XI', u'Asia'),
#  (1976, u'Innsbruck', u'Austria', u'winter', u'XII', u'Europe'),
#  (1980, u'Lake Placid', u'United States', u'winter', u'XIII', u'North America'),
#  (1984, u'Sarajevo', u'Yugoslavia', u'winter', u'XIV', u'Europe'),
#  (1988, u'Calgary', u'Canada', u'winter', u'XV', u'North America'),
#  (1992, u'Albertville', u'France', u'winter', u'XVI', u'Europe'),
#  (1994, u'Lillehammer', u'Norway', u'winter', u'XVII', u'Europe'),
#  (1998, u'Nagano', u'Japan', u'winter', u'XVIII', u'Asia'),
#  (2002, u'Salt Lake City', u'United States', u'winter', u'XIX', u'North America'),
#  (2006, u'Turin', u'Italy', u'winter', u'XX', u'Europe'),
#  (2010, u'Vancouver', u'Canada', u'winter', u'XXI', u'North America'),
#  (2014, u'Sochi', u'Russia', u'winter', u'XXII', u'Europe'),
#  (2018, u'Pyeongchang', u'South Korea', u'winter', u'XXIII', u'Asia'),
#  (1896, u'Athens', u'Greece', u'summer', u'I', u'Europe'),
#  (1900, u'Paris', u'France', u'summer', u'II', u'Europe'),
#  (1904, u'St. Louis', u'United States', u'summer', u'III', u'North America'),
#  (1908, u'London', u'United Kingdom', u'summer', u'IV', u'Europe'),
#  (1912, u'Stockholm', u'Sweden', u'summer', u'V', u'Europe'),
#  (1916, u'Berlin', u'Germany', u'summer', u'VI', u'Europe'),
#  (1920, u'Antwerp', u'Belgium', u'summer', u'VII', u'Europe'),
#  (1924, u'Paris', u'France', u'summer', u'VIII', u'Europe'),
#  (1928, u'Amsterdam', u'Netherlands', u'summer', u'IX', u'Europe'),
#  (1932, u'Los Angeles', u'United States', u'summer', u'X', u'North America'),
#  (1936, u'Berlin', u'Germany', u'summer', u'XI', u'Europe'),
#  (1948, u'London', u'United Kingdom', u'summer', u'XIV', u'Europe'),
#  (1952, u'Helsinki', u'Finland', u'summer', u'XV', u'Europe'),
#  (1956, u'Melbourne', u'Australia', u'summer', u'XVII', u'Australia'),
#  (1960, u'Rome', u'Italy', u'summer', u'XVII', u'Europe'),
#  (1964, u'Tokyo', u'Japan', u'summer', u'XVIII', u'Asia'),
#  (1968, u'Mexico City', u'Mexico', u'summer', u'XIX', u'North America'),
#  (1972, u'Munich', u'West Germany', u'summer', u'XX', u'Europe'),
#  (1976, u'Montreal', u'Canada', u'summer', u'XXI', u'North America'),
#  (1980, u'Moscow', u'Soviet Union', u'summer', u'XXII', u'Europe'),
#  (1984, u'Los Angeles', u'United States', u'summer', u'XXIII', u'North America'),
#  (1988, u'Seoul', u'South Korea', u'summer', u'XXIV', u'Asia'),
#  (1992, u'Barcelona', u'Spain', u'summer', u'XXV', u'Europe'),
#  (1996, u'Atlanta', u'United States', u'summer', u'XXVI', u'North America'),
#  (2000, u'Sydney', u'Australia', u'summer', u'XXVII', u'Australia'),
#  (2004, u'Athens', u'Greece', u'summer', u'XXVIII', u'Europe'),
#  (2008, u'Beijing', u'China', u'summer', u'XXIX', u'Asia'),
#  (2012, u'London', u'United Kingdom', u'summer', u'XXX', u'Europe'),
#  (2016, u'Rio de Janeiro', u'Brazil', u'summer', u'XXXI', u'South America')]

# %% [markdown]
# ## Instead of lists
#
# One of the 'rules' of relational databases is that the
# values in our tables must be primitive, we're not allowed to
# have lists or objects as values. This requirement is called
# the ["First normal
# form"](https://en.wikipedia.org/wiki/First_normal_form), or
# "1NF" -- we'll return to 'normal forms' during lectures 7
# and 8.
#
# If we were to write a program to keep track of the phone
# numbers of our friends, we could write something like this
# in Java:

# %% [markdown]
# ~~~java
# class Friend {
#
#     private String name;
#     private List<PhoneNumber> phoneNumbers;
#
#     ...
# }
#
# List<Friend> friends = ...
# ~~~

# %% [markdown]
# A literal translation of this into a table would be
# something like:

# %% [markdown]
# ~~~
# name      phone_numbers
# ----      -------------
# Adam      [123456, 654321]
# Bodil     [196811]
# ~~~

# %% [markdown]
# but this is in violation of the 'First normal form', so
# instead have a new row for each phone number:

# %% [markdown]
# ~~~
# name      phone
# ----      -----
# Adam      123456
# Adam      654321
# Bodil     196811
# ~~~

# %% [markdown]
# We can ask for Adam's number with:

# %% [markdown]
# ~~~sql
# SELECT phone
# FROM   friends
# WHERE  name = 'Adam'
# ~~~

# %% [markdown]
# and we'd get both numbers back:

# %% [markdown]
# ~~~
# phone
# -----
# 123456
# 654321
# ~~~

# %% [markdown]
# Now, assume we also want to save the birthdays of our
# friends. We could add a column for birthdays like this:

# %% [markdown]
# ~~~
# name    birthday    phone
# ----    --------    -----
# Adam    2 dec       123456
# Adam    2 dec       654321
# Bodil   30 nov      196811
# ~~~

# %% [markdown]
# What's the problem with this?
#
# And what if we also want to save our friends' email
# addresses:

# %% [markdown]
# ~~~
# name        birthday    phone       email
# ----        --------    -----       -----
# Adam        2 dec       123456      adam@gmail.com
# Adam        2 dec       123456      adam@yahoo.com
# Adam        2 dec       654321      adam@gmail.com
# Adam        2 dec       654321      adam@yahoo.com
# Bodil       30 nov      196811      bodil@itu.dk
# Bodil       30 nov      196811      bodil@lu.se
# Cecilia     9 apr       511235      cecilia@dn.se
# Cecilia     9 apr       641587      cecilia@dn.se
# David       12 jun      984531      david@gmail.co
# David       12 jun      984531      david@hotmail
# Emma        11 aug      123456      emma@lu.se
# ~~~

# %% [markdown]
# It may seem silly to have four rows for Adam, but if we
# removed one of them, we would loose vital information. If we
# removed the first row, and someone asked who had the phone
# number 123456 and the email address adam@gmail.com, the
# query:

# %% [markdown]
# ~~~sql
# SELECT  name, birthday
# FROM    friends
# WHERE   phone = '123456' AND email = 'adam@gmail.com'
# ~~~

# %% [markdown]
# would give an empty result.
#
# The problem with the table above is that we have a lot of
# redundance, i.e., information is repeated in many places.
# This is not only a waste of storage space, it also makes it
# much, much harder to work with our table -- insertions,
# updates and removals affects many rows, and if we're not
# careful, we might leave the table in a corrupted state.
#
# **Exercise:** _The data in the table above would be much
# easier to maintain if we split it into several tables --
# suggest how to do that._
#
#
# ## Views
#
# If we often use some query as part of other queries, we can
# save it using a _view_:

# %%
# %%sql
# CREATE VIEW application_info AS
#   SELECT s_id, s_name AS name, major, c_name AS college, state
#   FROM   applications
#   JOIN   students
#   USING  (s_id)
#   JOIN   colleges
#   USING  (c_name);
#
# SELECT DISTINCT name, state
# FROM   application_info
# WHERE  s_id IN (123, 234, 456);
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# Done.
# [(u'Amy', u'CA'), (u'Amy', u'NY'), (u'Bob', u'CA')]

# %% [markdown]
# **Exercise:** _Show the year and category for everyone who
# has won more than one Nobel Prize -- use a view to do it._
#
# <!---
# CREATE VIEW multiple_awards AS
#   SELECT name
#   FROM   nobel
#   GROUP BY laureate
#   HAVING COUNT() > 1;
#
# SELECT year, category, name
# FROM   multiple_awards
# JOIN   nobel
# USING  (name)
# ORDER BY year;
# -->
#
# We first create a view with the names of laureates with
# multiple awards:

# %%
# %%sql
#
# CREATE VIEW multiple_awards4 AS
#     SELECT name
#     FROM nobel
#     GROUP BY name
#     HAVING count() > 1;
#
# DROP VIEW IF EXISTS multiple_awards;
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# Done.
# []

# %% [markdown]
# and then use it to collect information about each of the
# awards:

# %%
# %%sql
# SELECT year, category
# FROM   multiple_awards
# Out:
#  * sqlite:///lect02.sqlite
# (sqlite3.OperationalError) no such table: multiple_awards
# [SQL: SELECT year, category
# FROM   multiple_awards]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# A view will be around until someone explicitly drops it:

# %%
# %%sql
# DROP VIEW IF EXISTS multiple_awards;
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# []

# %% [markdown]
# ## The `WITH`-statement
#
# As an alternative to views, we have _Common Table
# Expressions_ (or _CTE_'s) -- they are a kind of named view
# which is only used in a single query:

# %%
# %%sql
# WITH multiple_awards AS
#   (SELECT name
#    FROM   nobel
#    GROUP BY name
#    HAVING COUNT() > 1)
# SELECT year, category, name
# FROM   multiple_awards
# JOIN   nobel
# USING  (name)
# ORDER BY year;
# Out:
#  * sqlite:///lect02.sqlite
# Done.
# [(1903, u'physics', u'Marie Curie, n\xe9e Sklodowska'),
#  (1911, u'chemistry', u'Marie Curie, n\xe9e Sklodowska'),
#  (1956, u'physics', u'John Bardeen'),
#  (1958, u'chemistry', u'Frederick Sanger'),
#  (1972, u'physics', u'John Bardeen'),
#  (1980, u'chemistry', u'Frederick Sanger')]

# %% [markdown]
# Unlike views, tables created with `WITH` will 'disappear' as
# soon as our query is finished, one point of the `WITH`
# statement is that it's part of one single query (whereas the
# creation of a view is a statement itself) -- this will
# become useful when we make calls to our database from other
# programs (in lecture 7 and 8).
#
#
# We can't have another `WHERE` after the `HAVING` clause:

# %%
# %%sql
# SELECT    category, count() AS cnt
# FROM      nobel
# WHERE     year = 2013
# GROUP BY  category
# HAVING    count() < 3
# WHERE     cnt > 1        -- not allowed!

# %% [markdown]
# but we can make our 'grouping query' into a subquery, and
# have another `WHERE` in the outer query

# %%
# %%sql
# SELECT category, cnt
# FROM (
#     SELECT    category, count() AS cnt
#     FROM      nobel
#     WHERE     year = 2013
#     GROUP BY  category
#     HAVING    count() < 3)
# WHERE cnt > 1

# %% [markdown]
# A somewhat tidier way of expressing this is to use a
# `WITH`-statement -- we can write either:

# %%
# %%sql
# WITH category_count AS (
#     SELECT    category, count() AS cnt
#     FROM      nobel
#     WHERE     year = 2013
#     GROUP BY  category
#     HAVING    count() < 3
# )
# SELECT category, cnt
# FROM   category_count
# WHERE  cnt > 1

# %% [markdown]
# or

# %%
# %%sql
# WITH category_count(category, cnt) AS (
#     SELECT    category, count()
#     FROM      nobel
#     WHERE     year = 2013
#     GROUP BY  category
#     HAVING    count() < 3
# )
# SELECT category, cnt
# FROM   category_count
# WHERE  cnt > 1
