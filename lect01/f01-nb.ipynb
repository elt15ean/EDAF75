# %% [markdown]
# <!-- -*- mode: markdown; coding: utf-8; fill-column: 60; ispell-dictionary: "english" -*- -->
#
# <meta charset="utf-8"/>
# <meta name="viewport" content="width=device-width,initial-scale=1"/>
# <link rel="stylesheet" href="../style.css">
#
#
# # Our first Jupyter notebook
#
# This is a [_Jupyter notebook_](https://jupyter.org/), it
# contains _cells_ in which we can evaluate program code.
#
# There is built in support for _Julia_, _Python_, and _R_
# (hence _Ju-Pyt-R_), here's some Python code:

# %%
def hello(name):
    printf("hello, {name}!")

def main():
    name = input("What's your name: ")
    hello(name)
    
main()
# Out:
# What's your name: Edvin
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5fb8c00bfb2f> in <module>()
#       6     hello(name)
#       7
# ----> 8 main()
#
# <ipython-input-2-5fb8c00bfb2f> in main()
#       3
#       4 def main():
# ----> 5     name = input("What's your name: ")
#       6     hello(name)
#       7
#
# /home/edvin/.local/lib/python2.7/site-packages/ipykernel/ipkernel.pyc in <lambda>(prompt)
#     174             self._sys_eval_input = builtin_mod.input
#     175             builtin_mod.raw_input = self.raw_input
# --> 176             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     177         self._save_getpass = getpass.getpass
#     178         getpass.getpass = self.getpass
#
# /home/edvin/.local/lib/python2.7/site-packages/ipykernel/ipkernel.pyc in <module>()
#
# NameError: name 'Edvin' is not defined

# %% [markdown]
# You can run the code snippet above by clicking somewhere in
# the box, and press Shift-Enter.
#
# We're primarily going to run SQL code (see below) in our
# notebooks, but I'll also show you some Python code later on
# in the course.
#
# You don't have to learn Python to take this course, there
# will always be the option to use Java instead, but I
# encourage you to have a look at Python, since it is growing
# in popularity very quickly, and has become the 'lingua
# franca' of data science (together with R).
#
#
# ## Introduction to relational databases
#
# A [_Relational
# Database_](https://en.wikipedia.org/wiki/Relational_database)
# stores its data in [ _tables_
# ](https://en.wikipedia.org/wiki/Table_(database), where each
# table looks like a simple spreadsheet:
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;border-color:#999;margin:0px auto;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#999;color:#444;background-color:#F7FDFA;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#999;color:#fff;background-color:#26ADE4;}
# .tg .tg-e3zv{font-weight:bold}
# .tg .tg-9hbo{font-weight:bold;vertical-align:top}
# .tg .tg-yw4l{vertical-align:top}
# </style>
# <table class="tg">
#   <tr>
#     <th class="tg-e3zv">year</th>
#     <th class="tg-9hbo">category</th>
#     <th class="tg-9hbo">name</th>
#     <th class="tg-9hbo">motivation</th>
#   </tr>
#   <tr>
#     <td class="tg-yw4l">2011</td>
#     <td class="tg-yw4l">literature</td>
#     <td class="tg-yw4l">Tomas Tranströmer</td>
#     <td class="tg-yw4l">...</td>
#   </tr>
#   <tr>
#     <td class="tg-yw4l">2011</td>
#     <td class="tg-yw4l">physics</td>
#     <td class="tg-yw4l">Adam Riess</td>
#     <td class="tg-yw4l">...</td>
#   </tr>
#   <tr>
#     <td class="tg-yw4l">2011</td>
#     <td class="tg-yw4l">chemistry</td>
#     <td class="tg-yw4l">Dan Shechtman</td>
#     <td class="tg-yw4l">...</td>
#   </tr>
#   <tr>
#     <td class="tg-yw4l">2011</td>
#     <td class="tg-yw4l">medicine</td>
#     <td class="tg-yw4l">Ralph Steinman</td>
#     <td class="tg-yw4l">...</td>
#   </tr>
# </table>
#
# A _row_ represents an item, and a _column_ represents a
# property of the items.
#
# In the example above, each row describes a Nobel laurate,
# and for each laureate, we have columns showing what year the
# prize was awarded, in what category, the name of the
# laureate, and the motivation (not shown here).
#
# The basic idea of relational databases is that all 'cells'
# in the table should be simple values (no lists or objects!),
# and that we can use simple operations from [_relational
# algebra_](https://en.wikipedia.org/wiki/Relational_algebra)
# to get information from it. We do it using a programming
# language which is highly specialized for extracting
# information, it is called
# [SQL](https://en.wikipedia.org/wiki/SQL), which is short
# hand for _Structured Query Language_. SQL can be pronounced
# as either "S-Q-L", or "sequel".
#
# SQL is divided into several sub-languages:
#
#  + _DDL_ (_Data Definition Language_): constructs used to
#    define the tables of a database,
#
#  + _DML_ (_Data Manipulation Language_): statements used to
#    query and manipulate data in a database,
#
#  + _TCL_ (_Transaction Control Language_): commands used to
#    handle transactions (we will return to what a transaction
#    is later in the course), and
#
#  + _DCL_ (_Data Control Language_): commands used to
#    controll access to our data (we'll will not deal with
#    them in this course).
#
# This week we'll focus on DML, i.e., ways to query our
# databases -- next week we'll look at how to design and
# define our databases.
#
# Today, we'll discuss the following operations:
#
#  + _selection_: choosing some of the rows of a table
#
#  + _projection_: choosing some of the columns of a table
#
#  + _union_ and _intersection_: combining the rows of two
#    tables into one table (the tables we combine must be
#    compatible, which means that they must have the same
#    columns)
#
# Next time we'll study some other very important operations,
# which allows us to join several tables in interesting ways.
#
# ## An actual DBMS
#
# There are many different Relational Database Management
# Systems
# ([RDMBS:es](https://en.wikipedia.org/wiki/Relational_database))
# which implements SQL, some of the most prominent are:
#
#  *  [PostgreSQL](https://en.wikipedia.org/wiki/PostgreSQL)
#  *  [Oracle](https://en.wikipedia.org/wiki/Oracle_Database)
#  *  [MariaDB](https://en.wikipedia.org/wiki/MariaDB)
#  *  [MySQL](https://en.wikipedia.org/wiki/MySQL)
#  *  [Microsoft SQL Server](https://en.wikipedia.org/wiki/Microsoft_SQL_Server)
#  *  [IBM DD2](https://en.wikipedia.org/wiki/IBM_Db2_Family)
#  *  [SQLite](https://en.wikipedia.org/wiki/SQLite)
#
# In this course we'll use
# [SQLite](https://en.wikipedia.org/wiki/SQLite), which is a
# lightweight but still very powerful system -- it is _by far_
# the most used DBMS, and it's probably already running on all
# of your phones and computers (just as an example, if you use
# the Chrome for browsing, your browsing history is typically
# saved in a SQL-database file
# `.config/google-chrome/Default/History `).
#
# The `SQLite` file `lect01.sqlite` contains all Nobel
# Laureates in Physicis, Chemistry, Medicine, and Literature
# since 1901 (the Economics prize isn't really a Nobel prize,
# its an award given since 1969 by Riksbanken in memory of
# Alfred Nobel, and the Peace Prize is awarded by Norwegians).
# At the bottom of this page there's a description of how I
# created the database.
#
# To be able to write SQL queries in this notebook, we first
# have to run:

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# And to work with our database, we import it with:

# %%
# %sql sqlite:///lect01.sqlite
# Out:
# u'Connected: @lect01.sqlite'

# %% [markdown]
# Now we're good to go, we just have to prefix our SQL queries
# with `%sql` (one line of SQL) or `%%sql` (several lines of
# SQL, this is the form we will use in most cases).
#
# ## Some queries
#
# A simple _SQL query_ can be written as:

# %% [markdown]
# ~~~{.text}
# SELECT <what we're looking for>
# FROM   <what table we're looking in>
# ~~~

# %% [markdown]
# This selects all rows of a given table. If we're only
# interesting in some of the rows, and we normally are, we
# write:

# %% [markdown]
# ~~~{.text}
# SELECT <what we're looking for>
# FROM   <what table we're looking in>
# WHERE  <what items we're interested in>
# ~~~

# %% [markdown]
# The latter form is so common that it's got its own acronym:
# "SFW" (short for `SELECT`-`FROM`-`WHERE`).
#
# Our Nobel Database contains the following information for
# each laureate:
#
#  *  the _year_ the prize was awarded
#  *  the _category_ ('physics', 'chemistry', 'medicine',
#     'literature')
#  *  the _name_
#  *  the _motivation_
#
# Let's use the first form above to see all Nobel prizes which
# has been handed out:

# %%
# %%sql
# SELECT *
# FROM nobel
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1901, u'chemistry', u"Jacobus Henricus van 't Hoff", u'in recognition of the extraordinary services he has rendered by the discovery of the laws of chemical dynamics and osmotic pressure in solutions'),
#  (1901, u'literature', u'Sully Prudhomme', u'in special recognition of his poetic composition, which gives evidence of lofty idealism, artistic perfection and a rare combination of the qualities of both heart and intellect'),
#  (1901, u'medicine', u'Emil Adolf von Behring', u'for his work on serum therapy, especially its application against diphtheria, by which he has opened a new road in the domain of medical science and thereby placed in the hands of the physician a victorious weapon against illness and deaths'),
#  (1901, u'physics', u'Wilhelm Conrad R\xf6ntgen', u'in recognition of the extraordinary services he has rendered by the discovery of the remarkable rays subsequently named after him'),
#  (1902, u'chemistry', u'Hermann Emil Fischer', u'in recognition of the extraordinary services he has rendered by his work on sugar and purine syntheses'),
#  (1902, u'literature', u'Christian Matthias Theodor Mommsen', u'the greatest living master of the art of historical writing, with special reference to his monumental work, A history of Rome'),
#  (1902, u'medicine', u'Ronald Ross', u'for his work on malaria, by which he has shown how it enters the organism and thereby has laid the foundation for successful research on this disease and methods of combating it'),
#  (1902, u'physics', u'Hendrik Antoon Lorentz', u'in recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena'),
#  (1902, u'physics', u'Pieter Zeeman', u'in recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena'),
#  (1903, u'chemistry', u'Svante August Arrhenius', u'in recognition of the extraordinary services he has rendered to the advancement of chemistry by his electrolytic theory of dissociation'),
#  (1903, u'literature', u'Bj\xf8rnstjerne Martinus Bj\xf8rnson', u'as a tribute to his noble, magnificent and versatile poetry, which has always been distinguished by both the freshness of its inspiration and the rare purity of its spirit'),
#  (1903, u'medicine', u'Niels Ryberg Finsen', u'in recognition of his contribution to the treatment of diseases, especially lupus vulgaris, with concentrated light radiation, whereby he has opened a new avenue for medical science'),
#  (1903, u'physics', u'Antoine Henri Becquerel', u'in recognition of the extraordinary services he has rendered by his discovery of spontaneous radioactivity'),
#  (2007, u'medicine', u'Oliver Smithies', u'for their discoveries of principles for introducing specific gene modifications in mice by the use of embryonic stem cells'),
#  (2007, u'medicine', u'Sir Martin J. Evans', u'for their discoveries of principles for introducing specific gene modifications in mice by the use of embryonic stem cells'),
#  (2007, u'physics', u'Albert Fert', u'for the discovery of Giant Magnetoresistance'),
#  (2007, u'physics', u'Peter Gr\xfcnberg', u'for the discovery of Giant Magnetoresistance'),
#  (2008, u'chemistry', u'Martin Chalfie', u'for the discovery and development of the green fluorescent protein, GFP'),
#  (2008, u'chemistry', u'Osamu Shimomura', u'for the discovery and development of the green fluorescent protein, GFP'),
#  (2008, u'chemistry', u'Roger Y. Tsien', u'for the discovery and development of the green fluorescent protein, GFP'),
#  (2008, u'literature', u'Jean-Marie Gustave Le Cl\xe9zio', u'author of new departures, poetic adventure and sensual ecstasy, explorer of a humanity beyond and below the reigning civilization'),
#  (2008, u'medicine', u'Fran\xe7oise Barr\xe9-Sinoussi', u'for their discovery of human immunodeficiency virus'),
#  (2008, u'medicine', u'Harald zur Hausen', u'for his discovery of human papilloma viruses causing cervical cancer'),
#  (2008, u'medicine', u'Luc Montagnier', u'for their discovery of human immunodeficiency virus'),
#  (2008, u'physics', u'Makoto Kobayashi', u'for the discovery of the origin of the broken symmetry which predicts the existence of at least three families of quarks in nature'),
#  (2008, u'physics', u'Toshihide Maskawa', u'for the discovery of the origin of the broken symmetry which predicts the existence of at least three families of quarks in nature'),
#  (2008, u'physics', u'Yoichiro Nambu', u'for the discovery of the mechanism of spontaneous broken symmetry in subatomic physics'),
#  (2009, u'chemistry', u'Ada E. Yonath', u'for studies of the structure and function of the ribosome'),
#  (2009, u'chemistry', u'Thomas A. Steitz', u'for studies of the structure and function of the ribosome'),
#  (2009, u'chemistry', u'Venkatraman Ramakrishnan', u'for studies of the structure and function of the ribosome'),
#  (2009, u'literature', u'Herta M\xfcller', u'who, with the concentration of poetry and the frankness of prose, depicts the landscape of the dispossessed'),
#  (2009, u'medicine', u'Carol W. Greider', u'for the discovery of how chromosomes are protected by telomeres and the enzyme telomerase'),
#  (2009, u'medicine', u'Elizabeth H. Blackburn', u'for the discovery of how chromosomes are protected by telomeres and the enzyme telomerase'),
#  (2009, u'medicine', u'Jack W. Szostak', u'for the discovery of how chromosomes are protected by telomeres and the enzyme telomerase'),
#  (2009, u'physics', u'Charles Kuen Kao', u'for groundbreaking achievements concerning the transmission of light in fibers for optical communication'),
#  (2009, u'physics', u'George E. Smith', u'for the invention of an imaging semiconductor circuit - the CCD sensor'),
#  (2009, u'physics', u'Willard S. Boyle', u'for the invention of an imaging semiconductor circuit - the CCD sensor'),
#  (2010, u'chemistry', u'Akira Suzuki', u'for palladium-catalyzed cross couplings in organic synthesis'),
#  (2010, u'chemistry', u'Ei-ichi Negishi', u'for palladium-catalyzed cross couplings in organic synthesis'),
#  (2010, u'chemistry', u'Richard F. Heck', u'for palladium-catalyzed cross couplings in organic synthesis'),
#  (2010, u'literature', u'Mario Vargas Llosa', u"for his cartography of structures of power and his trenchant images of the individual's resistance, revolt, and defeat"),
#  (2010, u'medicine', u'Robert G. Edwards', u'for the development of in vitro fertilization'),
#  (2010, u'physics', u'Andre Geim', u'for groundbreaking experiments regarding the two-dimensional material graphene'),
#  (2010, u'physics', u'Konstantin Novoselov', u'for groundbreaking experiments regarding the two-dimensional material graphene'),
#  (2011, u'chemistry', u'Dan Shechtman', u'for the discovery of quasicrystals'),
#  (2011, u'literature', u'Tomas Transtr\xf6mer', u'because, through his condensed, translucent images, he gives us fresh access to reality'),
#  (2011, u'medicine', u'Bruce A. Beutler', u'for their discoveries concerning the activation of innate immunity'),
#  (2011, u'medicine', u'Jules A. Hoffmann', u'for their discoveries concerning the activation of innate immunity'),
#  (2011, u'medicine', u'Ralph M. Steinman', u'for his discovery of the dendritic cell and its role in adaptive immunity'),
#  (2011, u'physics', u'Adam G. Riess', u'for the discovery of the accelerating expansion of the Universe through observations of distant supernovae'),
#  (2011, u'physics', u'Brian P. Schmidt', u'for the discovery of the accelerating expansion of the Universe through observations of distant supernovae'),
#  (2011, u'physics', u'Saul Perlmutter', u'for the discovery of the accelerating expansion of the Universe through observations of distant supernovae'),
#  (2012, u'chemistry', u'Brian K. Kobilka', u'for studies of G-protein-coupled receptors'),
#  (2012, u'chemistry', u'Robert J. Lefkowitz', u'for studies of G-protein-coupled receptors'),
#  (2012, u'literature', u'Mo Yan', u'who with hallucinatory realism merges folk tales, history and the contemporary'),
#  (2012, u'medicine', u'Shinya Yamanaka', u'for the discovery that mature cells can be reprogrammed to become pluripotent'),
#  (2012, u'medicine', u'Sir John B. Gurdon', u'for the discovery that mature cells can be reprogrammed to become pluripotent'),
#  (2012, u'physics', u'David J. Wineland', u'for ground-breaking experimental methods that enable measuring and manipulation of individual quantum systems'),
#  (2012, u'physics', u'Serge Haroche', u'for ground-breaking experimental methods that enable measuring and manipulation of individual quantum systems'),
#  (2013, u'chemistry', u'Arieh Warshel', u'for the development of multiscale models for complex chemical systems'),
#  (2013, u'chemistry', u'Martin Karplus', u'for the development of multiscale models for complex chemical systems'),
#  (2013, u'chemistry', u'Michael Levitt', u'for the development of multiscale models for complex chemical systems'),
#  (2013, u'literature', u'Alice Munro', u'master of the contemporary short story'),
#  (2013, u'medicine', u'James E. Rothman', u'for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells'),
#  (2013, u'medicine', u'Randy W. Schekman', u'for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells'),
#  (2013, u'medicine', u'Thomas C. S\xfcdhof', u'for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells'),
#  (2013, u'physics', u'Fran\xe7ois Englert', u"for the theoretical discovery of a mechanism that contributes to our understanding of the origin of mass of subatomic particles, and which recently was confirmed through the discovery of the predicted fundamental particle, by the ATLAS and CMS experiments at CERN's Large Hadron Collider"),
#  (2013, u'physics', u'Peter W. Higgs', u"for the theoretical discovery of a mechanism that contributes to our understanding of the origin of mass of subatomic particles, and which recently was confirmed through the discovery of the predicted fundamental particle, by the ATLAS and CMS experiments at CERN's Large Hadron Collider"),
#  (2014, u'chemistry', u'Eric Betzig', u'for the development of super-resolved fluorescence microscopy'),
#  (2014, u'chemistry', u'Stefan W. Hell', u'for the development of super-resolved fluorescence microscopy'),
#  (2014, u'chemistry', u'William E. Moerner', u'for the development of super-resolved fluorescence microscopy'),
#  (2014, u'literature', u'Patrick Modiano', u'for the art of memory with which he has evoked the most ungraspable human destinies and uncovered the life-world of the occupation'),
#  (2014, u'medicine', u'Edvard I. Moser', u'for their discoveries of cells that constitute a positioning system in the brain'),
#  (2014, u'medicine', u"John O'Keefe", u'for their discoveries of cells that constitute a positioning system in the brain'),
#  (2014, u'medicine', u'May-Britt Moser', u'for their discoveries of cells that constitute a positioning system in the brain'),
#  (2014, u'physics', u'Hiroshi Amano', u'for the invention of efficient blue light-emitting diodes which has enabled bright and energy-saving white light sources'),
#  (2014, u'physics', u'Isamu Akasaki', u'for the invention of efficient blue light-emitting diodes which has enabled bright and energy-saving white light sources'),
#  (2014, u'physics', u'Shuji Nakamura', u'for the invention of efficient blue light-emitting diodes which has enabled bright and energy-saving white light sources'),
#  (2015, u'chemistry', u'Aziz Sancar', u'for mechanistic studies of DNA repair'),
#  (2015, u'chemistry', u'Paul Modrich', u'for mechanistic studies of DNA repair'),
#  (2015, u'chemistry', u'Tomas Lindahl', u'for mechanistic studies of DNA repair'),
#  (2015, u'literature', u'Svetlana Alexievich', u'for her polyphonic writings, a monument to suffering and courage in our time'),
#  (2015, u'medicine', u'Satoshi \u014cmura', u'for their discoveries concerning a novel therapy against infections caused by roundworm parasites'),
#  (2015, u'medicine', u'William C. Campbell', u'for their discoveries concerning a novel therapy against infections caused by roundworm parasites'),
#  (2015, u'medicine', u'Youyou Tu', u'for her discoveries concerning a novel therapy against Malaria'),
#  (2015, u'physics', u'Arthur B. McDonald', u'for the discovery of neutrino oscillations, which shows that neutrinos have mass'),
#  (2015, u'physics', u'Takaaki Kajita', u'for the discovery of neutrino oscillations, which shows that neutrinos have mass'),
#  (2016, u'chemistry', u'Bernard L. Feringa', u'for the design and synthesis of molecular machines'),
#  (2016, u'chemistry', u'Jean-Pierre Sauvage', u'for the design and synthesis of molecular machines'),
#  (2016, u'chemistry', u'Sir J. Fraser Stoddart', u'for the design and synthesis of molecular machines'),
#  (2016, u'literature', u'Bob Dylan', u'for having created new poetic expressions within the great American song tradition'),
#  (2016, u'medicine', u'Yoshinori Ohsumi', u'for his discoveries of mechanisms for autophagy'),
#  (2016, u'physics', u'David J. Thouless', u'for theoretical discoveries of topological phase transitions and topological phases of matter'),
#  (2016, u'physics', u'F. Duncan M. Haldane', u'for theoretical discoveries of topological phase transitions and topological phases of matter'),
#  (2016, u'physics', u'J. Michael Kosterlitz', u'for theoretical discoveries of topological phase transitions and topological phases of matter'),
#  (2017, u'chemistry', u'Jacques Dubochet', u'for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution'),
#  (2017, u'chemistry', u'Joachim Frank', u'for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution'),
#  (2017, u'chemistry', u'Richard Henderson', u'for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution'),
#  (2017, u'literature', u'Kazuo Ishiguro', u'who, in novels of great emotional force, has uncovered the abyss beneath our illusory sense of connection with the world'),
#  (2017, u'medicine', u'Jeffrey C. Hall', u'for their discoveries of molecular mechanisms controlling the circadian rhythm'),
#  (2017, u'medicine', u'Michael Rosbash', u'for their discoveries of molecular mechanisms controlling the circadian rhythm'),
#  (2017, u'medicine', u'Michael W. Young', u'for their discoveries of molecular mechanisms controlling the circadian rhythm'),
#  (2017, u'physics', u'Barry C. Barish', u'for decisive contributions to the LIGO detector and the observation of gravitational waves'),
#  (2017, u'physics', u'Kip S. Thorne', u'for decisive contributions to the LIGO detector and the observation of gravitational waves'),
#  (2017, u'physics', u'Rainer Weiss', u'for decisive contributions to the LIGO detector and the observation of gravitational waves'),
#  (2018, u'physics', u'Arthur Ashkin', u'for the optical tweezers and their application to biological systems'),
#  (2018, u'physics', u'G\xe9rard Mourou', u'for their method of generating high-intensity, ultra-short optical pulses'),
#  (2018, u'physics', u'Donna Strickland', u'for their method of generating high-intensity, ultra-short optical pulses'),
#  (2018, u'chemistry', u'Frances H. Arnold', u'for the directed evolution of enzymes'),
#  (2018, u'chemistry', u'George P. Smith', u'for the phage display of peptides and antibodies'),
#  (2018, u'chemistry', u'Greg Winter', u'for the phage display of peptides and antibodies'),
#  (2018, u'medicine', u'James P. Allison', u'for their discovery of cancer therapy by inhibition of negative immune regulation'),
#  (2018, u'medicine', u'Taskuk Honjo', u'for their discovery of cancer therapy by inhibition of negative immune regulation'),
#  (2018, u'literature', u'Olga Tokarczuk', u'for a narrative imagination that with encyclopedic passion represents the crossing of boundaries as a form of life'),
#  (2019, u'literature', u'Peter Handke', u'to demonstrate the complete absence of "genius" and "taste" of the Swedish Academy'),
#  (2019, u'physics', u'James Peebles', u'for the discovery of an exoplanet orbiting a solar-type star'),
#  (2019, u'physics', u'Michel Mayor', u'for the discovery of an exoplanet orbiting a solar-type star'),
#  (2019, u'physics', u'Didier Queloz', u'for the discovery of an exoplanet orbiting a solar-type star'),
#  (2019, u'chemistry', u'John B. Goodenough', u'for the development of lithium ion batteries'),
#  (2019, u'chemistry', u'M. Stanley Wittingham', u'for the development of lithium ion batteries'),
#  (2019, u'chemistry', u'Akira Yoshino', u'for the development of lithium ion batteries'),
#  (2019, u'medicine', u'William Kaelin Jr.', u'for their discoveries of how cells sense and adapt to oxygen availability'),
#  (2019, u'medicine', u'Peter J. Ratcliffe', u'for their discoveries of how cells sense and adapt to oxygen availability'),
#  (2019, u'medicine', u'Gregg L. Semenza', u'for their discoveries of how cells sense and adapt to oxygen availability')]

# %% [markdown]
# This is too much to look through, so let's first limit the
# output to 10 rows:

# %%
# %%sql
# SELECT *
# FROM nobel
# LIMIT 10
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1901, u'chemistry', u"Jacobus Henricus van 't Hoff", u'in recognition of the extraordinary services he has rendered by the discovery of the laws of chemical dynamics and osmotic pressure in solutions'),
#  (1901, u'literature', u'Sully Prudhomme', u'in special recognition of his poetic composition, which gives evidence of lofty idealism, artistic perfection and a rare combination of the qualities of both heart and intellect'),
#  (1901, u'medicine', u'Emil Adolf von Behring', u'for his work on serum therapy, especially its application against diphtheria, by which he has opened a new road in the domain of medical science and thereby placed in the hands of the physician a victorious weapon against illness and deaths'),
#  (1901, u'physics', u'Wilhelm Conrad R\xf6ntgen', u'in recognition of the extraordinary services he has rendered by the discovery of the remarkable rays subsequently named after him'),
#  (1902, u'chemistry', u'Hermann Emil Fischer', u'in recognition of the extraordinary services he has rendered by his work on sugar and purine syntheses'),
#  (1902, u'literature', u'Christian Matthias Theodor Mommsen', u'the greatest living master of the art of historical writing, with special reference to his monumental work, A history of Rome'),
#  (1902, u'medicine', u'Ronald Ross', u'for his work on malaria, by which he has shown how it enters the organism and thereby has laid the foundation for successful research on this disease and methods of combating it'),
#  (1902, u'physics', u'Hendrik Antoon Lorentz', u'in recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena'),
#  (1902, u'physics', u'Pieter Zeeman', u'in recognition of the extraordinary service they rendered by their researches into the influence of magnetism upon radiation phenomena'),
#  (1903, u'chemistry', u'Svante August Arrhenius', u'in recognition of the extraordinary services he has rendered to the advancement of chemistry by his electrolytic theory of dissociation')]

# %% [markdown]
# We can also _select_ only those prizes awarded in 2013.

# %%
# %%sql
# SELECT *
# FROM nobel
# WHERE year is 2013
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(2013, u'chemistry', u'Arieh Warshel', u'for the development of multiscale models for complex chemical systems'),
#  (2013, u'chemistry', u'Martin Karplus', u'for the development of multiscale models for complex chemical systems'),
#  (2013, u'chemistry', u'Michael Levitt', u'for the development of multiscale models for complex chemical systems'),
#  (2013, u'literature', u'Alice Munro', u'master of the contemporary short story'),
#  (2013, u'medicine', u'James E. Rothman', u'for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells'),
#  (2013, u'medicine', u'Randy W. Schekman', u'for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells'),
#  (2013, u'medicine', u'Thomas C. S\xfcdhof', u'for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells'),
#  (2013, u'physics', u'Fran\xe7ois Englert', u"for the theoretical discovery of a mechanism that contributes to our understanding of the origin of mass of subatomic particles, and which recently was confirmed through the discovery of the predicted fundamental particle, by the ATLAS and CMS experiments at CERN's Large Hadron Collider"),
#  (2013, u'physics', u'Peter W. Higgs', u"for the theoretical discovery of a mechanism that contributes to our understanding of the origin of mass of subatomic particles, and which recently was confirmed through the discovery of the predicted fundamental particle, by the ATLAS and CMS experiments at CERN's Large Hadron Collider")]

# %% [markdown]
# Observe that the query returns a new table, we'll soon see
# that we can use the returned table in other queries.
#
# **Q:** _What year did Einstein get his award, and why?_
#
# This requires both a _selection_ (the row with Einstein's
# award) and a _projection_ (only the year and motivation):

# %%
# %%sql
# SELECT motivation
# FROM nobel
# WHERE name is "Albert Einstein"
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'for his services to Theoretical Physics, and especially for his discovery of the law of the photoelectric effect',)]

# %% [markdown]
# Observe that the selection (what rows we're interested in)
# is given in the `WHERE` clause, whereas the projection (what
# columns we're interested in) is defined in the `SELECT`
# clause (the naming is somewhat counter-intuitive).
#
# The names of the columns in the returned table is shown
# above the actual output, if we want to rename any of the
# columns in the returned table, we can use an _alias_:

# %%
# %%sql
# SELECT year, motivation as reason
# FROM nobel
# WHERE name is 'Albert Einstein'
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1921, u'for his services to Theoretical Physics, and especially for his discovery of the law of the photoelectric effect')]

# %% [markdown]
# **Q:** _Who was awarded the physics prize in 1922?_

# %%
# %%sql
# SELECT name
# FROM nobel
# WHERE year = 1922
#         AND category = 'physics'
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Niels Henrik David Bohr',)]

# %% [markdown]
# **Q:** _Who were awarded the physics prize in 1922 and
# 1923?_ (Solve this problem in at least three different
# ways).

# %%
# %%sql
# SELECT name
# FROM nobel
# WHERE category = 'physics' AND year IN (1922, 1923)
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Niels Henrik David Bohr',), (u'Robert Andrews Millikan',)]

# %%
# %%sql
# SELECT name
# FROM nobel
# WHERE category = 'physics' AND year BETWEEN 1922 AND 1923
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Niels Henrik David Bohr',), (u'Robert Andrews Millikan',)]

# %%
# %%sql
# SELECT name
# FROM nobel
# WHERE category is 'physics' AND year is 1922
# UNION
# SELECT name
# FROM nobel
# WHERE category is 'physics' AND year is 1923
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Niels Henrik David Bohr',), (u'Robert Andrews Millikan',)]

# %% [markdown]
# There are often several ways of doing things in SQL, and one
# of the main points of using SQL is that the RDBMS tries to
# optimize the operations it needs to fetch our data (there is
# some seriously clever code running behind the scenes).
#
# **Q:** _Who has been awarded the prize in medicine since
# 2010, ordered by name?_

# %%
# %%sql
# SELECT name
# FROM nobel
# WHERE category is 'medicine' AND year >= 2010
# ORDER BY motivation
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Youyou Tu',),
#  (u'Yoshinori Ohsumi',),
#  (u'Ralph M. Steinman',),
#  (u'Robert G. Edwards',),
#  (u'Shinya Yamanaka',),
#  (u'Sir John B. Gurdon',),
#  (u'Satoshi \u014cmura',),
#  (u'William C. Campbell',),
#  (u'Bruce A. Beutler',),
#  (u'Jules A. Hoffmann',),
#  (u'Edvard I. Moser',),
#  (u"John O'Keefe",),
#  (u'May-Britt Moser',),
#  (u'William Kaelin Jr.',),
#  (u'Peter J. Ratcliffe',),
#  (u'Gregg L. Semenza',),
#  (u'James E. Rothman',),
#  (u'Randy W. Schekman',),
#  (u'Thomas C. S\xfcdhof',),
#  (u'Jeffrey C. Hall',),
#  (u'Michael Rosbash',),
#  (u'Michael W. Young',),
#  (u'James P. Allison',),
#  (u'Taskuk Honjo',)]

# %% [markdown]
# **Q:** _What year did Winston Churchill win a prize, and in
# what category?_

# %%
# %%sql
# SELECT year, category, name
# FROM nobel
# WHERE name LIKE '%Winston%Churchill%'
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1953, u'literature', u'Sir Winston Leonard Spencer Churchill')]

# %% [markdown]
# Using `LIKE` in our conditions, we get some rudimentary form
# of wildcard matching (some SQL databases allow more advanced
# regular expressions, but that's beyond the scope of this
# course).
#
#
# If we want to categorize our output, we can use a `CASE`
# statement, it has the general form:

# %% [markdown]
# ~~~sql
# SELECT ...,
#        CASE
#            WHEN ... THEN ...
#            WHEN ... THEN ...
#            ELSE ...
#        END AS <name>
# FROM ...
# ~~~

# %% [markdown]
# **Q:** _Show all laureates in physics with a name beginning
# with 'P', if they won the prize before 1970 they're ancient,
# if the won the prize between 1970 and 2000 they're veterans,
# otherwise they're newbies._

# %%
# %%sql
# SELECT year, name,
#     CASE
#         WHEN year < 1970 THEN 'ancient'
#         WHEN year BETWEEN 1970 AND 2000 THEN 'veteran'
#         ELSE 'newbie'
#         END AS 'street credentials'
# FROM nobel
# WHERE name LIKE "P%" AND category = 'physics'
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1902, u'Pieter Zeeman', u'ancient'),
#  (1903, u'Pierre Curie', u'ancient'),
#  (1905, u'Philipp Eduard Anton von Lenard', u'ancient'),
#  (1929, u'Prince Louis-Victor Pierre Raymond de Broglie', u'ancient'),
#  (1933, u'Paul Adrien Maurice Dirac', u'ancient'),
#  (1946, u'Percy Williams Bridgman', u'ancient'),
#  (1948, u'Patrick Maynard Stuart Blackett', u'ancient'),
#  (1955, u'Polykarp Kusch', u'ancient'),
#  (1958, u'Pavel Alekseyevich Cherenkov', u'ancient'),
#  (1977, u'Philip Warren Anderson', u'veteran'),
#  (1978, u'Pyotr Leonidovich Kapitsa', u'veteran'),
#  (1991, u'Pierre-Gilles de Gennes', u'veteran'),
#  (2007, u'Peter Gr\xfcnberg', u'newbie'),
#  (2013, u'Peter W. Higgs', u'newbie')]

# %% [markdown]
# ### `SELECT` and `SELECT DISTINCT`
#
# **Q:** _What are the different categories of Nobel prizes?_

# %%
# %%sql
# SELECT DISTINCT category
# FROM nobel
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'chemistry',), (u'literature',), (u'medicine',), (u'physics',)]

# %% [markdown]
# Using `SELECT DISTINCT` we only get unique rows in our
# output table.
#
#
# ### Using functions and aggregate functions
#
# There are some functions we can apply to our values, each
# RDBMS supplies their own set of functions. For example,
# SQLite has a `substr` function:

# %% [markdown]
# ~~~sql
# substr(value, first_pos, [length])
# ~~~

# %% [markdown]
# **Q:** _What was the initial letters of the laureates in
# year 2000?_

# %%
# %%sql
# SELECT substr(name, 1, 1) as initials, name
# FROM nobel
# WHERE year is 2000
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'A', u'Alan G. MacDiarmid'),
#  (u'A', u'Alan J. Heeger'),
#  (u'H', u'Hideki Shirakawa'),
#  (u'G', u'Gao Xingjian'),
#  (u'A', u'Arvid Carlsson'),
#  (u'E', u'Eric R. Kandel'),
#  (u'P', u'Paul Greengard'),
#  (u'H', u'Herbert Kroemer'),
#  (u'J', u'Jack S. Kilby'),
#  (u'Z', u'Zhores I. Alferov')]

# %% [markdown]
# An _aggregate function_ can be applied to all rows in a
# table, and then returns only one value.
#
# The standard aggregate functions are:
#
#  + `AVG`: calculates the average for a given column
#  + `COUNT`: counts the rows in a given table
#  + `MIN`: gets the minimum value of a given column
#  + `MAX`: gets the maximum value of a given column
#  + `SUM`: calculates the sum of a given column
#
#
# **Q:** _How many of the laureates has had a first name
# beginning with an 'A'?_

# %%
# %%sql
# SELECT count() as Count
# FROM nobel
# WHERE substr(name, 1, 1) is 'A'
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(60,)]

# %% [markdown]
# **Q:** _What year was the first Nobel prize awarded?_

# %%
# %%sql
# SELECT min(year)
# FROM nobel
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1901,)]

# %% [markdown]
# **Q:** _How many Nobel prizes for chemistry has been
# awarded?_

# %%
# %%sql
# SELECT count() as number_of_chemistry_awards
# FROM nobel
# WHERE category is 'chemistry'
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(184,)]

# %% [markdown]
# ### Groups and aggregates
#
# Using `GROUP BY` we can handle rows in groups -- to
# understand how it works, lets first look at the following
# query:

# %%
# %%sql
# SELECT    year, category, name
# FROM      nobel
# WHERE     year = 2013
# ORDER BY  category
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(2013, u'chemistry', u'Arieh Warshel'),
#  (2013, u'chemistry', u'Martin Karplus'),
#  (2013, u'chemistry', u'Michael Levitt'),
#  (2013, u'literature', u'Alice Munro'),
#  (2013, u'medicine', u'James E. Rothman'),
#  (2013, u'medicine', u'Randy W. Schekman'),
#  (2013, u'medicine', u'Thomas C. S\xfcdhof'),
#  (2013, u'physics', u'Fran\xe7ois Englert'),
#  (2013, u'physics', u'Peter W. Higgs')]

# %% [markdown]
# Here the rows of each category will end up adjacent to each
# other, and using `GROUP BY` we insert an invisible divider
# between the groups, and perform any aggregate function on
# the whole 'group':

# %%
# %%sql
# SELECT    category, count()
# FROM      nobel
# WHERE     year = 2013
# GROUP BY  category
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'chemistry', 3), (u'literature', 1), (u'medicine', 3), (u'physics', 2)]

# %% [markdown]
# So, if we apply an aggregate function, such as `count()`, in
# a table which we have grouped, it will be applied to each
# group, not to the whole table. Instead of getting one
# `count()` for the whole table (it would be a single value),
# we get one `count()` for each group (as above).
#
# If we add `name` in the first line, we get a somewhat
# arbitrary result:

# %%
# %%sql
# SELECT    category, count(), name
# FROM      nobel
# WHERE     year = 2013
# GROUP BY  category
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'chemistry', 3, u'Michael Levitt'),
#  (u'literature', 1, u'Alice Munro'),
#  (u'medicine', 3, u'Thomas C. S\xfcdhof'),
#  (u'physics', 2, u'Peter W. Higgs')]

# %% [markdown]
# The category and count is correct, but only one name is
# shown for each category.
#
# The 'problem' is that we only get one row per group in the
# output, and that there may be several laureates in each
# group -- our query will return one of them in a seemingly
# haphazard manner. We can concatenate all names in the group
# using the `group_concat`-function:

# %%
# %%sql
# SELECT    category, count(), group_concat(name)
# FROM      nobel
# WHERE     year = 2013
# GROUP BY  category
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'chemistry', 3, u'Arieh Warshel,Martin Karplus,Michael Levitt'),
#  (u'literature', 1, u'Alice Munro'),
#  (u'medicine', 3, u'James E. Rothman,Randy W. Schekman,Thomas C. S\xfcdhof'),
#  (u'physics', 2, u'Fran\xe7ois Englert,Peter W. Higgs')]

# %% [markdown]
# There is no problem displaying `category` in the
# `SELECT`-statement above, we get a value which we know is
# the same for each row in the group (by definition, since
# that's what we grouped by).
#
#
# If we're only interested in those categories with less than
# three laureates, we use `HAVING` to select only _groups_
# with a given property:

# %%
# %%sql
# SELECT    category, count(), group_concat(name)
# FROM      nobel
# WHERE     year = 2013
# GROUP BY  category
# HAVING    count() < 3
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'literature', 1, u'Alice Munro'),
#  (u'physics', 2, u'Fran\xe7ois Englert,Peter W. Higgs')]

# %% [markdown]
# This corresponds to a `WHERE` statement, but it applies to
# groups, not to individual rows (as `WHERE` does). In the
# query above we first have a `WHERE` statement to select some
# rows from the whole table, and then group the resulting
# selection.
#
#
#
# **Q:** _How many laureates are there in each category? Which
# category has seen the most laureates?_

# %%
# %%sql
# SELECT category, count()
# FROM nobel
# GROUP BY category
# ORDER BY count() DESC
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'medicine', 219),
#  (u'physics', 213),
#  (u'chemistry', 184),
#  (u'literature', 116)]

# %% [markdown]
# **Q:** _How many olympic games has each continent hosted?_

# %%
# %%sql
# SELECT continent, count()
# FROM olympics
# GROUP BY continent
# ORDER BY count() DESC
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Europe', 31),
#  (u'North America', 12),
#  (u'Asia', 6),
#  (u'Australia', 2),
#  (u'South America', 1)]

# %% [markdown]
# **Q:** _When was the first olympic games in each continent?_

# %%
# %%sql
# SELECT continent, min(year) as first_year
# FROM olympics
# GROUP BY continent
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Asia', 1964),
#  (u'Australia', 1956),
#  (u'Europe', 1896),
#  (u'North America', 1904),
#  (u'South America', 2016)]

# %% [markdown]
# **Q:** _Which countries has hosted the summer olympics more
# than once?_

# %%
# %%sql
# SELECT country, count()
# FROM olympics
# WHERE season is 'summer'
# GROUP BY country
# HAVING count() is 4
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'United States', 4)]

# %% [markdown]
# **Q:** _List the continents in descending order by the
# number of times they've hosted the summer olympics_

# %%
# %%sql
# SELECT continent, count()
# FROM olympics
# WHERE season is 'summer'
# GROUP BY continent
# ORDER BY count() DESC
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Europe', 17),
#  (u'North America', 6),
#  (u'Asia', 3),
#  (u'Australia', 2),
#  (u'South America', 1)]

# %% [markdown]
# **Q:** _Show an 'histogram' over the the initial letter of
# the names of all Nobel laureates_

# %%
# %%sql
# SELECT
# FROM nobel
# WHERE substr(name, 1, 1) is

# %% [markdown]
# We can group by more than one column, we now insert
# invisible borders between all combinations of the given
# column values:
#
#
# **Q:** _Show an 'histogram' over the the initial letter of
# the names of all Nobel laureates, **for each category**_

# %%
# %%sql
# SELECT substr(name, 1, 1) as initial, count(), category
# FROM nobel
# GROUP BY initial
# HAVING
# Out:
#  * sqlite:///lect01.sqlite
# (sqlite3.OperationalError) near "GROUP": syntax error
# [SQL: SELECT substr(name, 1, 1) as initial, count(), category
# FROM nobel
# GROUP BY initial
# GROUP BY category]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# **Q:** _Has anyone won more than one Nobel prize?_

# %%
# %%sql
# SELECT name, count()
# FROM nobel
# GROUP BY name
# HAVING count() > 1
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Frederick Sanger', 2),
#  (u'John Bardeen', 2),
#  (u'Marie Curie, n\xe9e Sklodowska', 2)]

# %% [markdown]
# **Q:** _Has anyone won more than one Nobel prize in the same
# category?_

# %%
# %%sql
# SELECT name
# FROM nobel
# GROUP BY name, category
# HAVING count() > 1
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(u'Frederick Sanger',), (u'John Bardeen',)]

# %% [markdown]
# ### Subqueries
#
# As we noted above, the result of a `SELECT`-statement is
# itself a table, and we can use such a table inside other
# statements.
#
# One useful pattern is:

# %% [markdown]
# ~~~sql
# SELECT ...
# FROM   ...
# WHERE  ... IN
#        (SELECT ...
#         FROM ...
#         WHERE ...)
# ~~~

# %% [markdown]
# The second query is called a _subquery_.
#
#
# **Q:** _Has the Nobel prize for literature ever been split?_

# %%
# %%sql
# SELECT year
# FROM nobel
# WHERE category is 'literature'
# GROUP BY year
# HAVING count() > 1
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1904,), (1917,), (1966,), (1974,)]

# %% [markdown]
# **Q:** _Which literature laureates split their prizes?_

# %%
# %%sql
# SELECT year, name
# FROM nobel
# WHERE category is 'literature' AND year IN
#                         (SELECT year
#                         FROM nobel
#                         WHERE category is 'literature'
#                         GROUP BY year
#                         HAVING count() > 1)
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# [(1904, u'Fr\xe9d\xe9ric Mistral'),
#  (1904, u'Jos\xe9 Echegaray y Eizaguirre'),
#  (1917, u'Henrik Pontoppidan'),
#  (1917, u'Karl Adolph Gjellerup'),
#  (1966, u'Nelly Sachs'),
#  (1966, u'Shmuel Yosef Agnon'),
#  (1974, u'Eyvind Johnson'),
#  (1974, u'Harry Martinson')]

# %% [markdown]
# There is another form of subquery which we'll return to
# later.
#
# **Q:** _Who has won the literature prize in a year when at
# least one chemistry laureate had a name beginning with 'L'?_

# %%
# %%sql
# SELECT name
# FROM nobel
# WHERE category is 'literature' IN (
#                                 SELECT name
#                                 FROM nobel
#                                 WHERE substr(name, 1, 1) is 'L' AND category is 'chemistry')
# Out:
#  * sqlite:///lect01.sqlite
# Done.
# []

# %% [markdown]
# **Q:** _Who has shared the chemistry prize with exactly one
# other laureate in years when the summer olympics were held
# in Europe?_

# %%
# %%sql

# %% [markdown]
# Another form of subquery is:

# %% [markdown]
# ~~~sql
# SELECT ...,
#        (SELECT ...
#         FROM ...
#         WHERE ...)
# FROM   ...
# ~~~

# %% [markdown]
# This works if the subquery produces one result, such as when
# we use an aggregate function. As an example, solve the
# following problem:
#
# **Q:** _Output the name of all laureates, and the number of
# awards they have -- order first by number of awards, then by
# name, and show only the first 20._

# %%
# %%sql

# %% [markdown]
# ~~~sql
# %%sql
#
# ~~~

# %% [markdown]
# This is called a _correlated subquery_ (since we refer to
# the enclosing query inside it). We use an alias to
# distinguish between the nobel table in the outer query and
# the nobel table in the subquery (it's the same table, but we
# 'iterate' through it separately).
#
# For the next lecture: is there any redundance in the table
# with the olympic games?
#
#
#
# ## Generating the database
#
# This is a description of how I created the database, it's
# just for the curious, and not part of the course.
#
# The data is copied from
# [`Nobelprize.org`](https://www.nobelprize.org/nobel_prizes/lists/all/create_list.html),
# and then pasted into a text file `nobel.csv` (`.csv` for
# comma-separated-values). I used `Emacs` to tidy things up
# (just some simple macros), and then I imported the text file
# into `sqlite` using the following script (I put it in the
# text file `nobel.sql`):

# %% [markdown]
# ~~~{sql}
# DROP TABLE IF EXISTS nobel;
# CREATE TABLE nobel (
#   year        INT,
#   category    TEXT,
#   name        TEXT,
#   motivation  TEXT
# );
#
# .mode csv
# .separator ';'
# .import nobel.csv nobel
# ~~~

# %% [markdown]
# To create a `sqlite`-file `nobel.sqlite` with all laureates,
# I only had to run the following command in a terminal (the
# exclamation sign tells `jupyter` to execute a shell
# command):

# %%
# !sqlite3 nobel.sqlite < nobel.sql

# %% [markdown]
# You can find information about running
# [SQLite](http://sqlite.org/) from a command line
# [here](https://sqlite.org/cli.html). I could have made
# things somewhat easier for myself by adding an extra header
# row first in my `.csv`-file, but I wanted to define the
# table myself, to make sure that `year` was saved as integers
# -- we'll return to this later in the course.
